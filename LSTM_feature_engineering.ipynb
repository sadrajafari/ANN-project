# %% [markdown]
# RNN-With Additional Features Engineered from the datasets

# %%
# !pip install opendatasets --quiet

# %%
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# %%
import opendatasets as od
od.download("https://www.kaggle.com/competitions/ventilator-pressure-prediction/data?select=train.csv")
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: sulovebhattarai
# Your Kaggle Key: ··········
# Downloading ventilator-pressure-prediction.zip to ./ventilator-pressure-prediction
# 100%|██████████| 223M/223M [00:00<00:00, 961MB/s]
# Extracting archive ./ventilator-pressure-prediction/ventilator-pressure-prediction.zip to ./ventilator-pressure-prediction

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %% [markdown]
# Load train and test datasets

# %%
train_df = pd.read_csv("/content/ventilator-pressure-prediction/train.csv")
test_df= pd.read_csv("/content/ventilator-pressure-prediction/test.csv")

# %% [markdown]
# ###### Additional Features:
# - **u_in_cumsum**: sum of air input to the lung
# - **u_in_lag1**: input flow just one step before
# - **u_out_lag1**: output valve (open or close) just one step before
# - **u_in_lag2**: input flow just two step before
# - **u_out_lag2**: output flow (open or close) just two step before
# - **u_in_lag_back1**: looks one step ahead inside same breath
# - **u_out_lag_back1**: output valve (open or close) one step in future
# - **u_in_lag_back2**: looks two step ahead inside same breath
# - **u_out_lag_back2**: output valve (open or close) two step in future

# %%
def add_breath_features(df):


    df['u_in_cumsum'] = df.groupby('breath_id')['u_in'].cumsum()


    df['u_in_lag1'] = df.groupby('breath_id')['u_in'].shift(1)
    df['u_out_lag1'] = df.groupby('breath_id')['u_out'].shift(1)

    df['u_in_lag2'] = df.groupby('breath_id')['u_in'].shift(2)
    df['u_out_lag2'] = df.groupby('breath_id')['u_out'].shift(2)


    df['u_in_lag_back1'] = df.groupby('breath_id')['u_in'].shift(-1)
    df['u_out_lag_back1'] = df.groupby('breath_id')['u_out'].shift(-1)

    df['u_in_lag_back2'] = df.groupby('breath_id')['u_in'].shift(-2)
    df['u_out_lag_back2'] = df.groupby('breath_id')['u_out'].shift(-2)

    return df

# %%
train_df = add_breath_features(train_df)
test_df  = add_breath_features(test_df)

# %%
train_df = pd.get_dummies(train_df, columns=["R","C"])
test_df  = pd.get_dummies(test_df,  columns=["R","C"])

# %%
train_df = train_df.fillna(0)
test_df  = test_df.fillna(0)

# %%
numeric_cols = [
    "time_step", "u_in",
    "u_in_cumsum",
    "u_in_lag1", "u_out_lag1",
    "u_in_lag2", "u_out_lag2",
    "u_in_lag_back1", "u_out_lag_back1",
    "u_in_lag_back2", "u_out_lag_back2"
]

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %% [markdown]
# Data Standarization

# %%
scaler = StandardScaler()
train_df[numeric_cols] = scaler.fit_transform(train_df[numeric_cols])
test_df[numeric_cols]  = scaler.transform(test_df[numeric_cols])

# %%
feature_cols = [c for c in train_df.columns if c not in ["id","pressure","breath_id"]]

# %% [markdown]
# Grouping of each breath into a sequence and converting to numpy array

# %%
X = train_df.groupby("breath_id")[feature_cols].apply(
        lambda x: x.to_numpy(dtype=np.float32)
    ).to_list()
y = train_df.groupby("breath_id")["pressure"].apply(
        lambda x: x.to_numpy(dtype=np.float32)
    ).to_list()
X_test = test_df.groupby("breath_id")[feature_cols].apply(
            lambda x: x.to_numpy(dtype=np.float32)
        ).to_list()


X = np.array(X)
y = np.array(y)
X_test = np.array(X_test)

# %% [markdown]
# Dividing train datasets into two parts.
# - **Training**: 90 %
# - **Validation**: 10%

# %%
X_train, X_val, y_train, y_val = train_test_split(
    X, y, test_size=0.1, random_state=42
)

# %% [markdown]
# Dataset class to communicate with Data loader

# %%
class VentilatorDataset(Dataset):
    def __init__(self, X, y=None):
        self.X = torch.tensor(X, dtype=torch.float32)
        self.y = None if y is None else torch.tensor(y, dtype=torch.float32)
    def __len__(self):
        return len(self.X)
    def __getitem__(self, idx):
        if self.y is None:
            return self.X[idx]
        return self.X[idx], self.y[idx]


train_loader = DataLoader(VentilatorDataset(X_train, y_train), batch_size=64, shuffle=True)
val_loader   = DataLoader(VentilatorDataset(X_val,   y_val),   batch_size=64)
test_loader  = DataLoader(VentilatorDataset(X_test), batch_size=64)

# %% [markdown]
# LSTM

# %%
class SimpleLSTM(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, dropout):
        super().__init__()

        self.lstm = nn.LSTM(
            input_size=input_size,
            hidden_size=hidden_size,
            num_layers=num_layers,
            dropout=dropout if num_layers > 1 else 0.0,
            batch_first=True
        )
        self.fc = nn.Linear(hidden_size, 1)

    def forward(self, x):
        out, _ = self.lstm(x)
        out = self.fc(out).squeeze(-1)
        return out


input_size = len(feature_cols)
criterion = nn.L1Loss()

# %% [markdown]
# Random choice of the hyperparameters to tune from

# %%
def sample_params():
    return {
        "hidden_size": random.choice([64, 128, 192]),
        "num_layers": random.choice([1, 2, 3]),
        "dropout": random.uniform(0.0, 0.4),
        "lr": 10 ** random.uniform(-4, -2)   # log-uniform LR
    }

# %%
N_TRIALS = 10
EPOCHS = 8

best_val_mae = float("inf")
best_params = None
best_state = None
results = []

# %%
import random

# %% [markdown]
# Trials to get the best hyperparameter, selecting the the one that gets low validation MAE

# %%
for trial in range(N_TRIALS):
    print(f"\nRandom Trial {trial+1}/{N_TRIALS} ")
    params = sample_params()
    hs, nl, dp, lr = params["hidden_size"], params["num_layers"], params["dropout"], params["lr"]
    print("Sampled Params:", params)

    # Build model
    model = SimpleLSTM(input_size, hs, nl, dp).to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode="min")

    train_hist = []
    val_hist = []

    for epoch in range(EPOCHS):
        model.train()
        train_loss = 0

        for Xb, yb in train_loader:
            Xb, yb = Xb.to(device), yb.to(device)

            optimizer.zero_grad()
            pred = model(Xb)
            loss = criterion(pred, yb)
            loss.backward()
            optimizer.step()
            train_loss += loss.item()

        train_loss /= len(train_loader)
        train_hist.append(train_loss)

        # Validation
        model.eval()
        val_loss = 0
        with torch.no_grad():
            for Xb, yb in val_loader:
                Xb, yb = Xb.to(device), yb.to(device)
                val_loss += criterion(model(Xb), yb).item()

        val_loss /= len(val_loader)
        val_hist.append(val_loss)

        scheduler.step(val_loss)

        print(f"Epoch {epoch+1}/{EPOCHS} | Train MAE={train_loss:.5f}, Val MAE={val_loss:.5f}")

    results.append((val_loss, params, train_hist, val_hist))

    if val_loss < best_val_mae:
        best_val_mae = val_loss
        best_params = params
        best_state = model.state_dict().copy()
        print("New BEST model found!")
# Out:
# Random Trial 1/10
# Sampled Params: {'hidden_size': 64, 'num_layers': 2, 'dropout': 0.3658473555497802, 'lr': 0.0006163558563420995}
# Epoch 1/8 | Train MAE=3.53597, Val MAE=1.43094
# Epoch 2/8 | Train MAE=1.16892, Val MAE=1.10893
# Epoch 3/8 | Train MAE=0.94824, Val MAE=0.85419
# Epoch 4/8 | Train MAE=0.86860, Val MAE=0.91929
# Epoch 5/8 | Train MAE=0.82589, Val MAE=0.74514
# Epoch 6/8 | Train MAE=0.79236, Val MAE=0.73204
# Epoch 7/8 | Train MAE=0.76594, Val MAE=0.73175
# Epoch 8/8 | Train MAE=0.74439, Val MAE=0.71721
# New BEST model found!
#
# Random Trial 2/10
# Sampled Params: {'hidden_size': 64, 'num_layers': 3, 'dropout': 0.2723732284993609, 'lr': 0.0008639859676156875}
# Epoch 1/8 | Train MAE=3.20944, Val MAE=1.12842
# Epoch 2/8 | Train MAE=0.99762, Val MAE=0.94622
# Epoch 3/8 | Train MAE=0.85060, Val MAE=0.75889
# Epoch 4/8 | Train MAE=0.79240, Val MAE=0.71960
# Epoch 5/8 | Train MAE=0.75511, Val MAE=0.70199
# Epoch 6/8 | Train MAE=0.72900, Val MAE=0.66459
# Epoch 7/8 | Train MAE=0.70959, Val MAE=0.65745
# Epoch 8/8 | Train MAE=0.68970, Val MAE=0.64085
# New BEST model found!
#
# Random Trial 3/10
# Sampled Params: {'hidden_size': 128, 'num_layers': 2, 'dropout': 0.3039771390703131, 'lr': 0.007880658546646746}
# Epoch 1/8 | Train MAE=1.82409, Val MAE=1.08674
# Epoch 2/8 | Train MAE=0.84296, Val MAE=0.82430
# Epoch 3/8 | Train MAE=0.74945, Val MAE=0.69623
# Epoch 4/8 | Train MAE=0.70524, Val MAE=0.88239
# Epoch 5/8 | Train MAE=0.68597, Val MAE=0.76605
# Epoch 6/8 | Train MAE=0.66440, Val MAE=0.62216
# Epoch 7/8 | Train MAE=0.64787, Val MAE=0.98211
# Epoch 8/8 | Train MAE=0.64837, Val MAE=0.65058
#
# Random Trial 4/10
# Sampled Params: {'hidden_size': 192, 'num_layers': 3, 'dropout': 0.3193345751563899, 'lr': 0.004160882523509269}
# Epoch 1/8 | Train MAE=1.66340, Val MAE=1.01526
# Epoch 2/8 | Train MAE=0.78236, Val MAE=0.80462
# Epoch 3/8 | Train MAE=0.70212, Val MAE=0.89246
# Epoch 4/8 | Train MAE=0.65696, Val MAE=0.83745
# Epoch 5/8 | Train MAE=0.63052, Val MAE=0.59437
# Epoch 6/8 | Train MAE=0.61107, Val MAE=0.59160
# Epoch 7/8 | Train MAE=0.58465, Val MAE=0.66524
# Epoch 8/8 | Train MAE=0.57277, Val MAE=0.58950
# New BEST model found!
#
# Random Trial 5/10
# Sampled Params: {'hidden_size': 128, 'num_layers': 2, 'dropout': 0.22046672333053202, 'lr': 0.0008865946441062367}
# Epoch 1/8 | Train MAE=2.15070, Val MAE=1.05945
# Epoch 2/8 | Train MAE=0.86605, Val MAE=0.95629
# Epoch 3/8 | Train MAE=0.77011, Val MAE=0.78082
# Epoch 4/8 | Train MAE=0.71779, Val MAE=0.94366
# Epoch 5/8 | Train MAE=0.68918, Val MAE=0.82975
# Epoch 6/8 | Train MAE=0.65522, Val MAE=0.62251
# Epoch 7/8 | Train MAE=0.63238, Val MAE=0.67984
# Epoch 8/8 | Train MAE=0.61598, Val MAE=0.57849
# New BEST model found!
#
# Random Trial 6/10
# Sampled Params: {'hidden_size': 64, 'num_layers': 3, 'dropout': 0.09813068609127536, 'lr': 0.007054263955412902}
# Epoch 1/8 | Train MAE=2.53997, Val MAE=1.29521
# Epoch 2/8 | Train MAE=0.91718, Val MAE=0.85023
# Epoch 3/8 | Train MAE=0.75946, Val MAE=0.84522
# Epoch 4/8 | Train MAE=0.70559, Val MAE=0.70429
# Epoch 5/8 | Train MAE=0.66493, Val MAE=0.64085
# Epoch 6/8 | Train MAE=0.64436, Val MAE=0.74721
# Epoch 7/8 | Train MAE=0.62881, Val MAE=0.60318
# Epoch 8/8 | Train MAE=0.61468, Val MAE=0.64559
#
# Random Trial 7/10
# Sampled Params: {'hidden_size': 128, 'num_layers': 1, 'dropout': 0.2051686125520955, 'lr': 0.00923434221510975}
# Epoch 1/8 | Train MAE=1.24842, Val MAE=1.48063
# Epoch 2/8 | Train MAE=0.78578, Val MAE=0.75710
# Epoch 3/8 | Train MAE=0.70896, Val MAE=0.79010
# Epoch 4/8 | Train MAE=0.68022, Val MAE=0.64748
# Epoch 5/8 | Train MAE=0.65022, Val MAE=0.77359
# Epoch 6/8 | Train MAE=0.63356, Val MAE=1.14199
# Epoch 7/8 | Train MAE=0.64142, Val MAE=0.73052
# Epoch 8/8 | Train MAE=0.61262, Val MAE=0.63525
#
# Random Trial 8/10
# Sampled Params: {'hidden_size': 64, 'num_layers': 3, 'dropout': 0.011817593786083602, 'lr': 0.00013617925624943205}
# Epoch 1/8 | Train MAE=5.62236, Val MAE=4.03156
# Epoch 2/8 | Train MAE=3.29814, Val MAE=2.54565
# Epoch 3/8 | Train MAE=2.00208, Val MAE=1.57578
# Epoch 4/8 | Train MAE=1.35413, Val MAE=1.21769
# Epoch 5/8 | Train MAE=1.11029, Val MAE=1.07382
# Epoch 6/8 | Train MAE=1.01413, Val MAE=1.02718
# Epoch 7/8 | Train MAE=0.96173, Val MAE=0.93111
# Epoch 8/8 | Train MAE=0.92591, Val MAE=0.89692
#
# Random Trial 9/10
# Sampled Params: {'hidden_size': 128, 'num_layers': 2, 'dropout': 0.26227707639188025, 'lr': 0.0005082290976912104}
# Epoch 1/8 | Train MAE=2.37621, Val MAE=1.17388
# Epoch 2/8 | Train MAE=0.97553, Val MAE=0.83321
# Epoch 3/8 | Train MAE=0.83815, Val MAE=0.95154
# Epoch 4/8 | Train MAE=0.78073, Val MAE=0.91292
# Epoch 5/8 | Train MAE=0.73585, Val MAE=0.67123
# Epoch 6/8 | Train MAE=0.70450, Val MAE=0.70418
# Epoch 7/8 | Train MAE=0.68119, Val MAE=0.67222
# Epoch 8/8 | Train MAE=0.66055, Val MAE=0.62697
#
# Random Trial 10/10
# Sampled Params: {'hidden_size': 192, 'num_layers': 2, 'dropout': 0.06351296030064045, 'lr': 0.00010618721589331388}
# Epoch 1/8 | Train MAE=3.65698, Val MAE=2.00323
# Epoch 2/8 | Train MAE=1.42733, Val MAE=1.15509
# Epoch 3/8 | Train MAE=1.09105, Val MAE=1.11268
# Epoch 4/8 | Train MAE=0.99260, Val MAE=0.97019
# Epoch 5/8 | Train MAE=0.91741, Val MAE=1.07407
# Epoch 6/8 | Train MAE=0.86133, Val MAE=0.83588
# Epoch 7/8 | Train MAE=0.81964, Val MAE=0.88457
# Epoch 8/8 | Train MAE=0.79518, Val MAE=0.75929

# %%
print("\nBest MAE:", best_val_mae)
print("Best Params:", best_params)
# Out:
# Best MAE: 0.5784946836657443
# Best Params: {'hidden_size': 128, 'num_layers': 2, 'dropout': 0.22046672333053202, 'lr': 0.0008865946441062367}

# %% [markdown]
# Training with the Best Hyperparameters
# - Training till 450 epochs
# - Adam opitmizer

# %%
hs, nl, dp, lr = best_params.values()

final_model = SimpleLSTM(input_size, hs, nl, dp).to(device)
optimizer = torch.optim.Adam(final_model.parameters(), lr=lr)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode="min")

FINAL_EPOCHS = 450
final_train_hist = []
final_val_hist = []

for epoch in range(FINAL_EPOCHS):
    final_model.train()
    train_loss = 0

    for Xb, yb in train_loader:
        Xb, yb = Xb.to(device), yb.to(device)
        optimizer.zero_grad()
        pred = final_model(Xb)
        loss = criterion(pred, yb)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()

    train_loss /= len(train_loader)
    final_train_hist.append(train_loss)

    final_model.eval()
    val_loss = 0
    with torch.no_grad():
        for Xb, yb in val_loader:
            Xb, yb = Xb.to(device), yb.to(device)
            val_loss += criterion(final_model(Xb), yb).item()

    val_loss /= len(val_loader)
    final_val_hist.append(val_loss)

    scheduler.step(val_loss)

    print(f"[FINAL] Epoch {epoch+1}/{FINAL_EPOCHS} | Train MAE={train_loss:.5f}, Val MAE={val_loss:.5f}")
# Out:
# [FINAL] Epoch 1/450 | Train MAE=2.05469, Val MAE=1.00376
# [FINAL] Epoch 2/450 | Train MAE=0.85779, Val MAE=0.79707
# [FINAL] Epoch 3/450 | Train MAE=0.76531, Val MAE=0.94793
# [FINAL] Epoch 4/450 | Train MAE=0.71324, Val MAE=0.64894
# [FINAL] Epoch 5/450 | Train MAE=0.67287, Val MAE=0.66262
# [FINAL] Epoch 6/450 | Train MAE=0.64688, Val MAE=0.60141
# [FINAL] Epoch 7/450 | Train MAE=0.62047, Val MAE=0.63479
# [FINAL] Epoch 8/450 | Train MAE=0.60472, Val MAE=0.57880
# [FINAL] Epoch 9/450 | Train MAE=0.58720, Val MAE=0.56294
# [FINAL] Epoch 10/450 | Train MAE=0.57697, Val MAE=0.57204
# [FINAL] Epoch 11/450 | Train MAE=0.56283, Val MAE=0.59442
# [FINAL] Epoch 12/450 | Train MAE=0.55227, Val MAE=0.67367
# [FINAL] Epoch 13/450 | Train MAE=0.55186, Val MAE=0.50779
# [FINAL] Epoch 14/450 | Train MAE=0.53275, Val MAE=0.51594
# [FINAL] Epoch 15/450 | Train MAE=0.52502, Val MAE=0.58575
# [FINAL] Epoch 16/450 | Train MAE=0.51820, Val MAE=0.50695
# [FINAL] Epoch 17/450 | Train MAE=0.50567, Val MAE=0.48655
# [FINAL] Epoch 18/450 | Train MAE=0.50413, Val MAE=0.49277
# [FINAL] Epoch 19/450 | Train MAE=0.49190, Val MAE=0.47887
# [FINAL] Epoch 20/450 | Train MAE=0.50402, Val MAE=0.46443
# [FINAL] Epoch 21/450 | Train MAE=0.47885, Val MAE=0.45221
# [FINAL] Epoch 22/450 | Train MAE=0.46791, Val MAE=0.44412
# [FINAL] Epoch 23/450 | Train MAE=0.45789, Val MAE=0.43866
# [FINAL] Epoch 24/450 | Train MAE=0.45465, Val MAE=0.44687
# [FINAL] Epoch 25/450 | Train MAE=0.45002, Val MAE=0.45954
# [FINAL] Epoch 26/450 | Train MAE=0.45146, Val MAE=0.45915
# [FINAL] Epoch 27/450 | Train MAE=0.43942, Val MAE=0.42893
# [FINAL] Epoch 28/450 | Train MAE=0.43604, Val MAE=0.41799
# [FINAL] Epoch 29/450 | Train MAE=0.42507, Val MAE=0.41042
# [FINAL] Epoch 30/450 | Train MAE=0.42640, Val MAE=0.41699
# [FINAL] Epoch 31/450 | Train MAE=0.41834, Val MAE=0.40315
# [FINAL] Epoch 32/450 | Train MAE=0.41484, Val MAE=0.46701
# [FINAL] Epoch 33/450 | Train MAE=0.43636, Val MAE=0.41875
# [FINAL] Epoch 34/450 | Train MAE=0.40885, Val MAE=0.41216
# [FINAL] Epoch 35/450 | Train MAE=0.41243, Val MAE=0.39775
# [FINAL] Epoch 36/450 | Train MAE=0.39862, Val MAE=0.39154
# [FINAL] Epoch 37/450 | Train MAE=0.39746, Val MAE=0.37564
# [FINAL] Epoch 38/450 | Train MAE=0.39349, Val MAE=0.36984
# [FINAL] Epoch 39/450 | Train MAE=0.39489, Val MAE=0.38584
# [FINAL] Epoch 40/450 | Train MAE=0.39043, Val MAE=0.37081
# [FINAL] Epoch 41/450 | Train MAE=0.38812, Val MAE=0.35908
# [FINAL] Epoch 42/450 | Train MAE=0.38542, Val MAE=0.38236
# [FINAL] Epoch 43/450 | Train MAE=0.38293, Val MAE=0.36001
# [FINAL] Epoch 44/450 | Train MAE=0.38480, Val MAE=0.39532
# [FINAL] Epoch 45/450 | Train MAE=0.37597, Val MAE=0.35803
# [FINAL] Epoch 46/450 | Train MAE=0.37143, Val MAE=0.36361
# [FINAL] Epoch 47/450 | Train MAE=0.37076, Val MAE=0.37085
# [FINAL] Epoch 48/450 | Train MAE=0.36500, Val MAE=0.34529
# [FINAL] Epoch 49/450 | Train MAE=0.36938, Val MAE=0.37333
# [FINAL] Epoch 50/450 | Train MAE=0.36621, Val MAE=0.35327
# [FINAL] Epoch 51/450 | Train MAE=0.37169, Val MAE=0.36187
# [FINAL] Epoch 52/450 | Train MAE=0.35960, Val MAE=0.34296
# [FINAL] Epoch 53/450 | Train MAE=0.35728, Val MAE=0.33422
# [FINAL] Epoch 54/450 | Train MAE=0.35773, Val MAE=0.35180
# [FINAL] Epoch 55/450 | Train MAE=0.35403, Val MAE=0.35697
# [FINAL] Epoch 56/450 | Train MAE=0.35218, Val MAE=0.33626
# [FINAL] Epoch 57/450 | Train MAE=0.35412, Val MAE=0.34318
# [FINAL] Epoch 58/450 | Train MAE=0.36607, Val MAE=0.33956
# [FINAL] Epoch 59/450 | Train MAE=0.35148, Val MAE=0.34612
# [FINAL] Epoch 60/450 | Train MAE=0.35808, Val MAE=0.35589
# [FINAL] Epoch 61/450 | Train MAE=0.34570, Val MAE=0.32670
# [FINAL] Epoch 62/450 | Train MAE=0.34868, Val MAE=0.35740
# [FINAL] Epoch 63/450 | Train MAE=0.34878, Val MAE=0.34948
# [FINAL] Epoch 64/450 | Train MAE=0.34499, Val MAE=0.32924
# [FINAL] Epoch 65/450 | Train MAE=0.34299, Val MAE=0.33218
# [FINAL] Epoch 66/450 | Train MAE=0.34979, Val MAE=0.32967
# [FINAL] Epoch 67/450 | Train MAE=0.34155, Val MAE=0.34734
# [FINAL] Epoch 68/450 | Train MAE=0.34271, Val MAE=0.33855
# [FINAL] Epoch 69/450 | Train MAE=0.34079, Val MAE=0.32457
# [FINAL] Epoch 70/450 | Train MAE=0.33685, Val MAE=0.31881
# [FINAL] Epoch 71/450 | Train MAE=0.33319, Val MAE=0.34996
# [FINAL] Epoch 72/450 | Train MAE=0.33937, Val MAE=0.34503
# [FINAL] Epoch 73/450 | Train MAE=0.34323, Val MAE=0.31513
# [FINAL] Epoch 74/450 | Train MAE=0.33525, Val MAE=0.34391
# [FINAL] Epoch 75/450 | Train MAE=0.34172, Val MAE=0.34302
# [FINAL] Epoch 76/450 | Train MAE=0.33028, Val MAE=0.32813
# [FINAL] Epoch 77/450 | Train MAE=0.34495, Val MAE=0.32399
# [FINAL] Epoch 78/450 | Train MAE=0.32509, Val MAE=0.32562
# [FINAL] Epoch 79/450 | Train MAE=0.33405, Val MAE=0.32099
# [FINAL] Epoch 80/450 | Train MAE=0.32754, Val MAE=0.31408
# [FINAL] Epoch 81/450 | Train MAE=0.32193, Val MAE=0.32284
# [FINAL] Epoch 82/450 | Train MAE=0.32969, Val MAE=0.31571
# [FINAL] Epoch 83/450 | Train MAE=0.32624, Val MAE=0.33400
# [FINAL] Epoch 84/450 | Train MAE=0.33387, Val MAE=0.31796
# [FINAL] Epoch 85/450 | Train MAE=0.32943, Val MAE=0.32786
# [FINAL] Epoch 86/450 | Train MAE=0.32500, Val MAE=0.30505
# [FINAL] Epoch 87/450 | Train MAE=0.32932, Val MAE=0.31138
# [FINAL] Epoch 88/450 | Train MAE=0.33132, Val MAE=0.32640
# [FINAL] Epoch 89/450 | Train MAE=0.32821, Val MAE=0.32144
# [FINAL] Epoch 90/450 | Train MAE=0.31907, Val MAE=0.31243
# [FINAL] Epoch 91/450 | Train MAE=0.32792, Val MAE=0.30549
# [FINAL] Epoch 92/450 | Train MAE=0.31479, Val MAE=0.31796
# [FINAL] Epoch 93/450 | Train MAE=0.31443, Val MAE=0.30935
# [FINAL] Epoch 94/450 | Train MAE=0.31546, Val MAE=0.30264
# [FINAL] Epoch 95/450 | Train MAE=0.31682, Val MAE=0.37716
# [FINAL] Epoch 96/450 | Train MAE=0.33382, Val MAE=0.30967
# [FINAL] Epoch 97/450 | Train MAE=0.31680, Val MAE=0.33669
# [FINAL] Epoch 98/450 | Train MAE=0.31672, Val MAE=0.51644
# [FINAL] Epoch 99/450 | Train MAE=0.34355, Val MAE=0.30692
# [FINAL] Epoch 100/450 | Train MAE=0.32224, Val MAE=0.31428
# [FINAL] Epoch 101/450 | Train MAE=0.32069, Val MAE=0.30129
# [FINAL] Epoch 102/450 | Train MAE=0.31118, Val MAE=0.33904
# [FINAL] Epoch 103/450 | Train MAE=0.31419, Val MAE=0.30430
# [FINAL] Epoch 104/450 | Train MAE=0.31150, Val MAE=0.32698
# [FINAL] Epoch 105/450 | Train MAE=0.31472, Val MAE=0.29938
# [FINAL] Epoch 106/450 | Train MAE=0.31666, Val MAE=0.31277
# [FINAL] Epoch 107/450 | Train MAE=0.34462, Val MAE=0.31246
# [FINAL] Epoch 108/450 | Train MAE=0.31339, Val MAE=0.32349
# [FINAL] Epoch 109/450 | Train MAE=0.30938, Val MAE=0.30549
# [FINAL] Epoch 110/450 | Train MAE=0.31497, Val MAE=0.29522
# [FINAL] Epoch 111/450 | Train MAE=0.31654, Val MAE=0.29963
# [FINAL] Epoch 112/450 | Train MAE=0.30598, Val MAE=0.38257
# [FINAL] Epoch 113/450 | Train MAE=0.31620, Val MAE=0.32164
# [FINAL] Epoch 114/450 | Train MAE=0.33108, Val MAE=0.29918
# [FINAL] Epoch 115/450 | Train MAE=0.30377, Val MAE=0.29552
# [FINAL] Epoch 116/450 | Train MAE=0.30702, Val MAE=0.29894
# [FINAL] Epoch 117/450 | Train MAE=0.30153, Val MAE=0.30725
# [FINAL] Epoch 118/450 | Train MAE=0.31413, Val MAE=0.32152
# [FINAL] Epoch 119/450 | Train MAE=0.31181, Val MAE=0.33821
# [FINAL] Epoch 120/450 | Train MAE=0.30785, Val MAE=0.28963
# [FINAL] Epoch 121/450 | Train MAE=0.30236, Val MAE=0.30081
# [FINAL] Epoch 122/450 | Train MAE=0.32727, Val MAE=0.30567
# [FINAL] Epoch 123/450 | Train MAE=0.30587, Val MAE=0.30209
# [FINAL] Epoch 124/450 | Train MAE=0.31602, Val MAE=0.32529
# [FINAL] Epoch 125/450 | Train MAE=0.30711, Val MAE=0.28722
# [FINAL] Epoch 126/450 | Train MAE=0.30464, Val MAE=0.29970
# [FINAL] Epoch 127/450 | Train MAE=0.29927, Val MAE=0.29921
# [FINAL] Epoch 128/450 | Train MAE=0.30211, Val MAE=0.32405
# [FINAL] Epoch 129/450 | Train MAE=0.30564, Val MAE=0.29570
# [FINAL] Epoch 130/450 | Train MAE=0.31283, Val MAE=0.32062
# [FINAL] Epoch 131/450 | Train MAE=0.30067, Val MAE=0.28506
# [FINAL] Epoch 132/450 | Train MAE=0.30167, Val MAE=0.28672
# [FINAL] Epoch 133/450 | Train MAE=0.30341, Val MAE=0.29005
# [FINAL] Epoch 134/450 | Train MAE=0.29546, Val MAE=0.29342
# [FINAL] Epoch 135/450 | Train MAE=0.29207, Val MAE=0.28085
# [FINAL] Epoch 136/450 | Train MAE=0.29836, Val MAE=0.29855
# [FINAL] Epoch 137/450 | Train MAE=0.29577, Val MAE=0.28234
# [FINAL] Epoch 138/450 | Train MAE=0.33329, Val MAE=0.30000
# [FINAL] Epoch 139/450 | Train MAE=0.30361, Val MAE=0.28958
# [FINAL] Epoch 140/450 | Train MAE=0.29678, Val MAE=0.29422
# [FINAL] Epoch 141/450 | Train MAE=0.31133, Val MAE=0.29340
# [FINAL] Epoch 142/450 | Train MAE=0.29820, Val MAE=0.32756
# [FINAL] Epoch 143/450 | Train MAE=0.29791, Val MAE=0.28274
# [FINAL] Epoch 144/450 | Train MAE=0.29921, Val MAE=0.28526
# [FINAL] Epoch 145/450 | Train MAE=0.29527, Val MAE=0.28519
# [FINAL] Epoch 146/450 | Train MAE=0.29021, Val MAE=0.28640
# [FINAL] Epoch 147/450 | Train MAE=0.27130, Val MAE=0.26740
# [FINAL] Epoch 148/450 | Train MAE=0.26737, Val MAE=0.26480
# [FINAL] Epoch 149/450 | Train MAE=0.26621, Val MAE=0.26460
# [FINAL] Epoch 150/450 | Train MAE=0.26558, Val MAE=0.26526
# [FINAL] Epoch 151/450 | Train MAE=0.26488, Val MAE=0.26482
# [FINAL] Epoch 152/450 | Train MAE=0.26489, Val MAE=0.26335
# [FINAL] Epoch 153/450 | Train MAE=0.26431, Val MAE=0.26396
# [FINAL] Epoch 154/450 | Train MAE=0.26412, Val MAE=0.26293
# [FINAL] Epoch 155/450 | Train MAE=0.26345, Val MAE=0.26356
# [FINAL] Epoch 156/450 | Train MAE=0.26332, Val MAE=0.26214
# [FINAL] Epoch 157/450 | Train MAE=0.26318, Val MAE=0.26206
# [FINAL] Epoch 158/450 | Train MAE=0.26314, Val MAE=0.26489
# [FINAL] Epoch 159/450 | Train MAE=0.26252, Val MAE=0.26209
# [FINAL] Epoch 160/450 | Train MAE=0.26217, Val MAE=0.26216
# [FINAL] Epoch 161/450 | Train MAE=0.26218, Val MAE=0.26234
# [FINAL] Epoch 162/450 | Train MAE=0.26365, Val MAE=0.26205
# [FINAL] Epoch 163/450 | Train MAE=0.26158, Val MAE=0.26154
# [FINAL] Epoch 164/450 | Train MAE=0.26334, Val MAE=0.26303
# [FINAL] Epoch 165/450 | Train MAE=0.26130, Val MAE=0.26168
# [FINAL] Epoch 166/450 | Train MAE=0.26174, Val MAE=0.26177
# [FINAL] Epoch 167/450 | Train MAE=0.26153, Val MAE=0.26223
# [FINAL] Epoch 168/450 | Train MAE=0.26170, Val MAE=0.26192
# [FINAL] Epoch 169/450 | Train MAE=0.26159, Val MAE=0.26244
# [FINAL] Epoch 170/450 | Train MAE=0.26063, Val MAE=0.26065
# [FINAL] Epoch 171/450 | Train MAE=0.26140, Val MAE=0.26678
# [FINAL] Epoch 172/450 | Train MAE=0.26103, Val MAE=0.26038
# [FINAL] Epoch 173/450 | Train MAE=0.26039, Val MAE=0.26107
# [FINAL] Epoch 174/450 | Train MAE=0.25976, Val MAE=0.26139
# [FINAL] Epoch 175/450 | Train MAE=0.25988, Val MAE=0.26173
# [FINAL] Epoch 176/450 | Train MAE=0.26073, Val MAE=0.26057
# [FINAL] Epoch 177/450 | Train MAE=0.26013, Val MAE=0.26320
# [FINAL] Epoch 178/450 | Train MAE=0.25961, Val MAE=0.26204
# [FINAL] Epoch 179/450 | Train MAE=0.26005, Val MAE=0.26091
# [FINAL] Epoch 180/450 | Train MAE=0.25937, Val MAE=0.26134
# [FINAL] Epoch 181/450 | Train MAE=0.25911, Val MAE=0.26073
# [FINAL] Epoch 182/450 | Train MAE=0.25891, Val MAE=0.26046
# [FINAL] Epoch 183/450 | Train MAE=0.25900, Val MAE=0.26034
# [FINAL] Epoch 184/450 | Train MAE=0.25959, Val MAE=0.26058
# [FINAL] Epoch 185/450 | Train MAE=0.25860, Val MAE=0.26265
# [FINAL] Epoch 186/450 | Train MAE=0.25835, Val MAE=0.25883
# [FINAL] Epoch 187/450 | Train MAE=0.25841, Val MAE=0.26150
# [FINAL] Epoch 188/450 | Train MAE=0.25827, Val MAE=0.25942
# [FINAL] Epoch 189/450 | Train MAE=0.25874, Val MAE=0.26122
# [FINAL] Epoch 190/450 | Train MAE=0.25819, Val MAE=0.25991
# [FINAL] Epoch 191/450 | Train MAE=0.25782, Val MAE=0.25998
# [FINAL] Epoch 192/450 | Train MAE=0.25770, Val MAE=0.25956
# [FINAL] Epoch 193/450 | Train MAE=0.25773, Val MAE=0.26054
# [FINAL] Epoch 194/450 | Train MAE=0.25817, Val MAE=0.26131
# [FINAL] Epoch 195/450 | Train MAE=0.25784, Val MAE=0.26047
# [FINAL] Epoch 196/450 | Train MAE=0.25749, Val MAE=0.26273
# [FINAL] Epoch 197/450 | Train MAE=0.25767, Val MAE=0.26059
# [FINAL] Epoch 198/450 | Train MAE=0.25561, Val MAE=0.25874
# [FINAL] Epoch 199/450 | Train MAE=0.25583, Val MAE=0.25854
# [FINAL] Epoch 200/450 | Train MAE=0.25505, Val MAE=0.25850
# [FINAL] Epoch 201/450 | Train MAE=0.25483, Val MAE=0.25859
# [FINAL] Epoch 202/450 | Train MAE=0.25501, Val MAE=0.25835
# [FINAL] Epoch 203/450 | Train MAE=0.25476, Val MAE=0.25818
# [FINAL] Epoch 204/450 | Train MAE=0.25502, Val MAE=0.25804
# [FINAL] Epoch 205/450 | Train MAE=0.25463, Val MAE=0.25848
# [FINAL] Epoch 206/450 | Train MAE=0.25504, Val MAE=0.25867
# [FINAL] Epoch 207/450 | Train MAE=0.25483, Val MAE=0.25820
# [FINAL] Epoch 208/450 | Train MAE=0.25445, Val MAE=0.25845
# [FINAL] Epoch 209/450 | Train MAE=0.25489, Val MAE=0.25815
# [FINAL] Epoch 210/450 | Train MAE=0.25490, Val MAE=0.25822
# [FINAL] Epoch 211/450 | Train MAE=0.25531, Val MAE=0.25817
# [FINAL] Epoch 212/450 | Train MAE=0.25445, Val MAE=0.25845
# [FINAL] Epoch 213/450 | Train MAE=0.25484, Val MAE=0.25814
# [FINAL] Epoch 214/450 | Train MAE=0.25473, Val MAE=0.25797
# [FINAL] Epoch 215/450 | Train MAE=0.25459, Val MAE=0.25822
# [FINAL] Epoch 216/450 | Train MAE=0.25467, Val MAE=0.25851
# [FINAL] Epoch 217/450 | Train MAE=0.25458, Val MAE=0.25819
# [FINAL] Epoch 218/450 | Train MAE=0.25460, Val MAE=0.25806
# [FINAL] Epoch 219/450 | Train MAE=0.25449, Val MAE=0.25782
# [FINAL] Epoch 220/450 | Train MAE=0.25478, Val MAE=0.25813
# [FINAL] Epoch 221/450 | Train MAE=0.25436, Val MAE=0.25789
# [FINAL] Epoch 222/450 | Train MAE=0.25446, Val MAE=0.25821
# [FINAL] Epoch 223/450 | Train MAE=0.25468, Val MAE=0.25811
# [FINAL] Epoch 224/450 | Train MAE=0.25551, Val MAE=0.25784
# [FINAL] Epoch 225/450 | Train MAE=0.25465, Val MAE=0.25828
# [FINAL] Epoch 226/450 | Train MAE=0.25455, Val MAE=0.25833
# [FINAL] Epoch 227/450 | Train MAE=0.25453, Val MAE=0.25787
# [FINAL] Epoch 228/450 | Train MAE=0.25498, Val MAE=0.25801
# [FINAL] Epoch 229/450 | Train MAE=0.25445, Val MAE=0.25849
# [FINAL] Epoch 230/450 | Train MAE=0.25426, Val MAE=0.25789
# [FINAL] Epoch 231/450 | Train MAE=0.25465, Val MAE=0.25802
# [FINAL] Epoch 232/450 | Train MAE=0.25451, Val MAE=0.25789
# [FINAL] Epoch 233/450 | Train MAE=0.25412, Val MAE=0.25801
# [FINAL] Epoch 234/450 | Train MAE=0.25438, Val MAE=0.25786
# [FINAL] Epoch 235/450 | Train MAE=0.25429, Val MAE=0.25791
# [FINAL] Epoch 236/450 | Train MAE=0.25455, Val MAE=0.25790
# [FINAL] Epoch 237/450 | Train MAE=0.25432, Val MAE=0.25772
# [FINAL] Epoch 238/450 | Train MAE=0.25403, Val MAE=0.25779
# [FINAL] Epoch 239/450 | Train MAE=0.25434, Val MAE=0.25786
# [FINAL] Epoch 240/450 | Train MAE=0.25446, Val MAE=0.25790
# [FINAL] Epoch 241/450 | Train MAE=0.25450, Val MAE=0.25781
# [FINAL] Epoch 242/450 | Train MAE=0.25419, Val MAE=0.25793
# [FINAL] Epoch 243/450 | Train MAE=0.25407, Val MAE=0.25796
# [FINAL] Epoch 244/450 | Train MAE=0.25421, Val MAE=0.25795
# [FINAL] Epoch 245/450 | Train MAE=0.25434, Val MAE=0.25786
# [FINAL] Epoch 246/450 | Train MAE=0.25396, Val MAE=0.25798
# [FINAL] Epoch 247/450 | Train MAE=0.25402, Val MAE=0.25792
# [FINAL] Epoch 248/450 | Train MAE=0.25424, Val MAE=0.25794
# [FINAL] Epoch 249/450 | Train MAE=0.25403, Val MAE=0.25792
# [FINAL] Epoch 250/450 | Train MAE=0.25439, Val MAE=0.25790
# [FINAL] Epoch 251/450 | Train MAE=0.25413, Val MAE=0.25790
# [FINAL] Epoch 252/450 | Train MAE=0.25430, Val MAE=0.25790
# [FINAL] Epoch 253/450 | Train MAE=0.25402, Val MAE=0.25789
# [FINAL] Epoch 254/450 | Train MAE=0.25397, Val MAE=0.25790
# [FINAL] Epoch 255/450 | Train MAE=0.25409, Val MAE=0.25788
# [FINAL] Epoch 256/450 | Train MAE=0.25383, Val MAE=0.25788
# [FINAL] Epoch 257/450 | Train MAE=0.25399, Val MAE=0.25788
# [FINAL] Epoch 258/450 | Train MAE=0.25403, Val MAE=0.25787
# [FINAL] Epoch 259/450 | Train MAE=0.25421, Val MAE=0.25788
# [FINAL] Epoch 260/450 | Train MAE=0.25396, Val MAE=0.25788
# [FINAL] Epoch 261/450 | Train MAE=0.25403, Val MAE=0.25788
# [FINAL] Epoch 262/450 | Train MAE=0.25424, Val MAE=0.25788
# [FINAL] Epoch 263/450 | Train MAE=0.25423, Val MAE=0.25788
# [FINAL] Epoch 264/450 | Train MAE=0.25441, Val MAE=0.25788
# [FINAL] Epoch 265/450 | Train MAE=0.25414, Val MAE=0.25788
# [FINAL] Epoch 266/450 | Train MAE=0.25409, Val MAE=0.25788
# [FINAL] Epoch 267/450 | Train MAE=0.25392, Val MAE=0.25788
# [FINAL] Epoch 268/450 | Train MAE=0.25413, Val MAE=0.25788
# [FINAL] Epoch 269/450 | Train MAE=0.25409, Val MAE=0.25788
# [FINAL] Epoch 270/450 | Train MAE=0.25427, Val MAE=0.25788
# [FINAL] Epoch 271/450 | Train MAE=0.25422, Val MAE=0.25788
# [FINAL] Epoch 272/450 | Train MAE=0.25423, Val MAE=0.25788
# [FINAL] Epoch 273/450 | Train MAE=0.25387, Val MAE=0.25788
# [FINAL] Epoch 274/450 | Train MAE=0.25411, Val MAE=0.25788
# [FINAL] Epoch 275/450 | Train MAE=0.25441, Val MAE=0.25788
# [FINAL] Epoch 276/450 | Train MAE=0.25422, Val MAE=0.25788
# [FINAL] Epoch 277/450 | Train MAE=0.25415, Val MAE=0.25788
# [FINAL] Epoch 278/450 | Train MAE=0.25439, Val MAE=0.25788
# [FINAL] Epoch 279/450 | Train MAE=0.25427, Val MAE=0.25788
# [FINAL] Epoch 280/450 | Train MAE=0.25397, Val MAE=0.25788
# [FINAL] Epoch 281/450 | Train MAE=0.25408, Val MAE=0.25788
# [FINAL] Epoch 282/450 | Train MAE=0.25451, Val MAE=0.25788
# [FINAL] Epoch 283/450 | Train MAE=0.25452, Val MAE=0.25788
# [FINAL] Epoch 284/450 | Train MAE=0.25409, Val MAE=0.25788
# [FINAL] Epoch 285/450 | Train MAE=0.25427, Val MAE=0.25788
# [FINAL] Epoch 286/450 | Train MAE=0.25425, Val MAE=0.25788
# [FINAL] Epoch 287/450 | Train MAE=0.25413, Val MAE=0.25788
# [FINAL] Epoch 288/450 | Train MAE=0.25421, Val MAE=0.25788
# [FINAL] Epoch 289/450 | Train MAE=0.25407, Val MAE=0.25788
# [FINAL] Epoch 290/450 | Train MAE=0.25422, Val MAE=0.25788
# [FINAL] Epoch 291/450 | Train MAE=0.25389, Val MAE=0.25788
# [FINAL] Epoch 292/450 | Train MAE=0.25436, Val MAE=0.25788
# [FINAL] Epoch 293/450 | Train MAE=0.25426, Val MAE=0.25788
# [FINAL] Epoch 294/450 | Train MAE=0.25425, Val MAE=0.25788
# [FINAL] Epoch 295/450 | Train MAE=0.25448, Val MAE=0.25788
# [FINAL] Epoch 296/450 | Train MAE=0.25418, Val MAE=0.25788
# [FINAL] Epoch 297/450 | Train MAE=0.25417, Val MAE=0.25788
# [FINAL] Epoch 298/450 | Train MAE=0.25451, Val MAE=0.25788
# [FINAL] Epoch 299/450 | Train MAE=0.25390, Val MAE=0.25788
# [FINAL] Epoch 300/450 | Train MAE=0.25426, Val MAE=0.25788
# [FINAL] Epoch 301/450 | Train MAE=0.25406, Val MAE=0.25788
# [FINAL] Epoch 302/450 | Train MAE=0.25445, Val MAE=0.25788
# [FINAL] Epoch 303/450 | Train MAE=0.25418, Val MAE=0.25788
# [FINAL] Epoch 304/450 | Train MAE=0.25409, Val MAE=0.25788
# [FINAL] Epoch 305/450 | Train MAE=0.25410, Val MAE=0.25788
# [FINAL] Epoch 306/450 | Train MAE=0.25384, Val MAE=0.25788
# [FINAL] Epoch 307/450 | Train MAE=0.25378, Val MAE=0.25788
# [FINAL] Epoch 308/450 | Train MAE=0.25407, Val MAE=0.25788
# [FINAL] Epoch 309/450 | Train MAE=0.25405, Val MAE=0.25788
# [FINAL] Epoch 310/450 | Train MAE=0.25415, Val MAE=0.25788
# [FINAL] Epoch 311/450 | Train MAE=0.25418, Val MAE=0.25788
# [FINAL] Epoch 312/450 | Train MAE=0.25442, Val MAE=0.25788
# [FINAL] Epoch 313/450 | Train MAE=0.25398, Val MAE=0.25788
# [FINAL] Epoch 314/450 | Train MAE=0.25423, Val MAE=0.25788
# [FINAL] Epoch 315/450 | Train MAE=0.25403, Val MAE=0.25788
# [FINAL] Epoch 316/450 | Train MAE=0.25416, Val MAE=0.25788
# [FINAL] Epoch 317/450 | Train MAE=0.25437, Val MAE=0.25788
# [FINAL] Epoch 318/450 | Train MAE=0.25409, Val MAE=0.25788
# [FINAL] Epoch 319/450 | Train MAE=0.25413, Val MAE=0.25788
# [FINAL] Epoch 320/450 | Train MAE=0.25392, Val MAE=0.25788
# [FINAL] Epoch 321/450 | Train MAE=0.25407, Val MAE=0.25788
# [FINAL] Epoch 322/450 | Train MAE=0.25421, Val MAE=0.25788
# [FINAL] Epoch 323/450 | Train MAE=0.25424, Val MAE=0.25788
# [FINAL] Epoch 324/450 | Train MAE=0.25425, Val MAE=0.25788
# [FINAL] Epoch 325/450 | Train MAE=0.25419, Val MAE=0.25788
# [FINAL] Epoch 326/450 | Train MAE=0.25416, Val MAE=0.25788
# [FINAL] Epoch 327/450 | Train MAE=0.25439, Val MAE=0.25788
# [FINAL] Epoch 328/450 | Train MAE=0.25406, Val MAE=0.25788
# [FINAL] Epoch 329/450 | Train MAE=0.25397, Val MAE=0.25788
# [FINAL] Epoch 330/450 | Train MAE=0.25412, Val MAE=0.25788
# [FINAL] Epoch 331/450 | Train MAE=0.25417, Val MAE=0.25788
# [FINAL] Epoch 332/450 | Train MAE=0.25421, Val MAE=0.25788
# [FINAL] Epoch 333/450 | Train MAE=0.25391, Val MAE=0.25788
# [FINAL] Epoch 334/450 | Train MAE=0.25420, Val MAE=0.25788
# [FINAL] Epoch 335/450 | Train MAE=0.25416, Val MAE=0.25788
# [FINAL] Epoch 336/450 | Train MAE=0.25393, Val MAE=0.25788
# [FINAL] Epoch 337/450 | Train MAE=0.25438, Val MAE=0.25788
# [FINAL] Epoch 338/450 | Train MAE=0.25429, Val MAE=0.25788
# [FINAL] Epoch 339/450 | Train MAE=0.25457, Val MAE=0.25788
# [FINAL] Epoch 340/450 | Train MAE=0.25402, Val MAE=0.25788
# [FINAL] Epoch 341/450 | Train MAE=0.25424, Val MAE=0.25788
# [FINAL] Epoch 342/450 | Train MAE=0.25393, Val MAE=0.25788
# [FINAL] Epoch 343/450 | Train MAE=0.25425, Val MAE=0.25788
# [FINAL] Epoch 344/450 | Train MAE=0.25402, Val MAE=0.25788
# [FINAL] Epoch 345/450 | Train MAE=0.25447, Val MAE=0.25788
# [FINAL] Epoch 346/450 | Train MAE=0.25397, Val MAE=0.25788
# [FINAL] Epoch 347/450 | Train MAE=0.25417, Val MAE=0.25788
# [FINAL] Epoch 348/450 | Train MAE=0.25642, Val MAE=0.25788
# [FINAL] Epoch 349/450 | Train MAE=0.25409, Val MAE=0.25788
# [FINAL] Epoch 350/450 | Train MAE=0.25424, Val MAE=0.25788
# [FINAL] Epoch 351/450 | Train MAE=0.25399, Val MAE=0.25788
# [FINAL] Epoch 352/450 | Train MAE=0.25442, Val MAE=0.25788
# [FINAL] Epoch 353/450 | Train MAE=0.25408, Val MAE=0.25788
# [FINAL] Epoch 354/450 | Train MAE=0.25423, Val MAE=0.25788
# [FINAL] Epoch 355/450 | Train MAE=0.25416, Val MAE=0.25788
# [FINAL] Epoch 356/450 | Train MAE=0.25375, Val MAE=0.25788
# [FINAL] Epoch 357/450 | Train MAE=0.25406, Val MAE=0.25788
# [FINAL] Epoch 358/450 | Train MAE=0.25397, Val MAE=0.25788
# [FINAL] Epoch 359/450 | Train MAE=0.25401, Val MAE=0.25788
# [FINAL] Epoch 360/450 | Train MAE=0.25393, Val MAE=0.25788
# [FINAL] Epoch 361/450 | Train MAE=0.25403, Val MAE=0.25788
# [FINAL] Epoch 362/450 | Train MAE=0.25398, Val MAE=0.25788
# [FINAL] Epoch 363/450 | Train MAE=0.25392, Val MAE=0.25788
# [FINAL] Epoch 364/450 | Train MAE=0.25423, Val MAE=0.25788
# [FINAL] Epoch 365/450 | Train MAE=0.25420, Val MAE=0.25788
# [FINAL] Epoch 366/450 | Train MAE=0.25395, Val MAE=0.25788
# [FINAL] Epoch 367/450 | Train MAE=0.25406, Val MAE=0.25788
# [FINAL] Epoch 368/450 | Train MAE=0.25419, Val MAE=0.25788
# [FINAL] Epoch 369/450 | Train MAE=0.25408, Val MAE=0.25788
# [FINAL] Epoch 370/450 | Train MAE=0.25409, Val MAE=0.25788
# [FINAL] Epoch 371/450 | Train MAE=0.25418, Val MAE=0.25788
# [FINAL] Epoch 372/450 | Train MAE=0.25401, Val MAE=0.25788
# [FINAL] Epoch 373/450 | Train MAE=0.25420, Val MAE=0.25788
# [FINAL] Epoch 374/450 | Train MAE=0.25386, Val MAE=0.25788
# [FINAL] Epoch 375/450 | Train MAE=0.25413, Val MAE=0.25788
# [FINAL] Epoch 376/450 | Train MAE=0.25418, Val MAE=0.25788
# [FINAL] Epoch 377/450 | Train MAE=0.25405, Val MAE=0.25788
# [FINAL] Epoch 378/450 | Train MAE=0.25444, Val MAE=0.25788
# [FINAL] Epoch 379/450 | Train MAE=0.25418, Val MAE=0.25788
# [FINAL] Epoch 380/450 | Train MAE=0.25433, Val MAE=0.25788
# [FINAL] Epoch 381/450 | Train MAE=0.25446, Val MAE=0.25788
# [FINAL] Epoch 382/450 | Train MAE=0.25432, Val MAE=0.25788
# [FINAL] Epoch 383/450 | Train MAE=0.25407, Val MAE=0.25788
# [FINAL] Epoch 384/450 | Train MAE=0.25426, Val MAE=0.25788
# [FINAL] Epoch 385/450 | Train MAE=0.25413, Val MAE=0.25788
# [FINAL] Epoch 386/450 | Train MAE=0.25426, Val MAE=0.25788
# [FINAL] Epoch 387/450 | Train MAE=0.25410, Val MAE=0.25788
# [FINAL] Epoch 388/450 | Train MAE=0.25417, Val MAE=0.25788
# [FINAL] Epoch 389/450 | Train MAE=0.25409, Val MAE=0.25788
# [FINAL] Epoch 390/450 | Train MAE=0.25475, Val MAE=0.25788
# [FINAL] Epoch 391/450 | Train MAE=0.25402, Val MAE=0.25788
# [FINAL] Epoch 392/450 | Train MAE=0.25400, Val MAE=0.25788
# [FINAL] Epoch 393/450 | Train MAE=0.25406, Val MAE=0.25788
# [FINAL] Epoch 394/450 | Train MAE=0.25401, Val MAE=0.25788
# [FINAL] Epoch 395/450 | Train MAE=0.25406, Val MAE=0.25788
# [FINAL] Epoch 396/450 | Train MAE=0.25439, Val MAE=0.25788
# [FINAL] Epoch 397/450 | Train MAE=0.25422, Val MAE=0.25788
# [FINAL] Epoch 398/450 | Train MAE=0.25412, Val MAE=0.25788
# [FINAL] Epoch 399/450 | Train MAE=0.25444, Val MAE=0.25788
# [FINAL] Epoch 400/450 | Train MAE=0.25400, Val MAE=0.25788
# [FINAL] Epoch 401/450 | Train MAE=0.25400, Val MAE=0.25788
# [FINAL] Epoch 402/450 | Train MAE=0.25404, Val MAE=0.25787
# [FINAL] Epoch 403/450 | Train MAE=0.25421, Val MAE=0.25788
# [FINAL] Epoch 404/450 | Train MAE=0.25449, Val MAE=0.25788
# [FINAL] Epoch 405/450 | Train MAE=0.25432, Val MAE=0.25788
# [FINAL] Epoch 406/450 | Train MAE=0.25399, Val MAE=0.25788
# [FINAL] Epoch 407/450 | Train MAE=0.25419, Val MAE=0.25788
# [FINAL] Epoch 408/450 | Train MAE=0.25418, Val MAE=0.25788
# [FINAL] Epoch 409/450 | Train MAE=0.25410, Val MAE=0.25788
# [FINAL] Epoch 410/450 | Train MAE=0.25428, Val MAE=0.25787
# [FINAL] Epoch 411/450 | Train MAE=0.25402, Val MAE=0.25787
# [FINAL] Epoch 412/450 | Train MAE=0.25412, Val MAE=0.25787
# [FINAL] Epoch 413/450 | Train MAE=0.25397, Val MAE=0.25788
# [FINAL] Epoch 414/450 | Train MAE=0.25414, Val MAE=0.25787
# [FINAL] Epoch 415/450 | Train MAE=0.25398, Val MAE=0.25787
# [FINAL] Epoch 416/450 | Train MAE=0.25432, Val MAE=0.25787
# [FINAL] Epoch 417/450 | Train MAE=0.25426, Val MAE=0.25788
# [FINAL] Epoch 418/450 | Train MAE=0.25422, Val MAE=0.25788
# [FINAL] Epoch 419/450 | Train MAE=0.25392, Val MAE=0.25788
# [FINAL] Epoch 420/450 | Train MAE=0.25412, Val MAE=0.25788
# [FINAL] Epoch 421/450 | Train MAE=0.25384, Val MAE=0.25788
# [FINAL] Epoch 422/450 | Train MAE=0.25406, Val MAE=0.25788
# [FINAL] Epoch 423/450 | Train MAE=0.25373, Val MAE=0.25788
# [FINAL] Epoch 424/450 | Train MAE=0.25452, Val MAE=0.25788
# [FINAL] Epoch 425/450 | Train MAE=0.25392, Val MAE=0.25788
# [FINAL] Epoch 426/450 | Train MAE=0.25434, Val MAE=0.25788
# [FINAL] Epoch 427/450 | Train MAE=0.25376, Val MAE=0.25788
# [FINAL] Epoch 428/450 | Train MAE=0.25432, Val MAE=0.25788
# [FINAL] Epoch 429/450 | Train MAE=0.25403, Val MAE=0.25788
# [FINAL] Epoch 430/450 | Train MAE=0.25417, Val MAE=0.25788
# [FINAL] Epoch 431/450 | Train MAE=0.25425, Val MAE=0.25788
# [FINAL] Epoch 432/450 | Train MAE=0.25422, Val MAE=0.25788
# [FINAL] Epoch 433/450 | Train MAE=0.25408, Val MAE=0.25788
# [FINAL] Epoch 434/450 | Train MAE=0.25411, Val MAE=0.25788
# [FINAL] Epoch 435/450 | Train MAE=0.25431, Val MAE=0.25788
# [FINAL] Epoch 436/450 | Train MAE=0.25404, Val MAE=0.25788
# [FINAL] Epoch 437/450 | Train MAE=0.25412, Val MAE=0.25788
# [FINAL] Epoch 438/450 | Train MAE=0.25407, Val MAE=0.25788
# [FINAL] Epoch 439/450 | Train MAE=0.25429, Val MAE=0.25788
# [FINAL] Epoch 440/450 | Train MAE=0.25408, Val MAE=0.25788
# [FINAL] Epoch 441/450 | Train MAE=0.25395, Val MAE=0.25788
# [FINAL] Epoch 442/450 | Train MAE=0.25402, Val MAE=0.25788
# [FINAL] Epoch 443/450 | Train MAE=0.25370, Val MAE=0.25788
# [FINAL] Epoch 444/450 | Train MAE=0.25404, Val MAE=0.25788
# [FINAL] Epoch 445/450 | Train MAE=0.25412, Val MAE=0.25788
# [FINAL] Epoch 446/450 | Train MAE=0.25420, Val MAE=0.25788
# [FINAL] Epoch 447/450 | Train MAE=0.25394, Val MAE=0.25788
# [FINAL] Epoch 448/450 | Train MAE=0.25420, Val MAE=0.25788
# [FINAL] Epoch 449/450 | Train MAE=0.25405, Val MAE=0.25788
# [FINAL] Epoch 450/450 | Train MAE=0.25411, Val MAE=0.25788

# %% [markdown]
# Visualization of Train MAE and Val MAE

# %%
plt.figure(figsize=(8,5))
plt.plot(final_train_hist, label="Train MAE")
plt.plot(final_val_hist, label="Validation MAE")
plt.xlabel("Epoch")
plt.ylabel("MAE")
plt.title("Training vs Validation MAE (LSTM)")
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# Testing of Trained LSTM on test data. <br>
#
# -Collection of prediction

# %%
preds = []
final_model.eval()

with torch.no_grad():
    for Xb in test_loader:
        Xb = Xb.to(device)
        pred = final_model(Xb)
        preds.append(pred.cpu().numpy())

preds = np.concatenate(preds).reshape(-1)
print("Test predictions shape:", preds.shape)
# Out:
# Test predictions shape: (4024000,)

# %% [markdown]
# Kaggle Submission requires the predictions to be in .csv format. <br>
# With two columns **ID** and **prediction** columns

# %%
submission = pd.DataFrame({
    "id": test_df["id"],
    "pressure": preds
})

submission.to_csv("LSTM_submission_differentfeatures.csv", index=False)
print("Saved submission.csv")
submission.head()
# Out:
# Saved submission.csv
#    id  pressure
# 0   1  6.110902
# 1   2  5.748463
# 2   3  6.877120
# 3   4  7.412261
# 4   5  8.786637

# %%
from google.colab import files

# Download a single file
files.download('LSTM_submission_differentfeatures.csv')
