# %% [markdown]
# RNN-With Additional Features Engineered from the datasets

# %%
# !pip install opendatasets --quiet

# %%
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# %%
import opendatasets as od
od.download("https://www.kaggle.com/competitions/ventilator-pressure-prediction/data?select=train.csv")
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: sulovebhattarai
# Your Kaggle Key: ··········
# Downloading ventilator-pressure-prediction.zip to ./ventilator-pressure-prediction
# 100%|██████████| 223M/223M [00:00<00:00, 408MB/s]
# Extracting archive ./ventilator-pressure-prediction/ventilator-pressure-prediction.zip to ./ventilator-pressure-prediction

# %% [markdown]
# Load train dataset

# %%
train_df = pd.read_csv("/content/ventilator-pressure-prediction/train.csv")

# %% [markdown]
# Load test datsets

# %%
test_df= pd.read_csv("/content/ventilator-pressure-prediction/test.csv")

# %% [markdown]
# ###### Additional Features:
# - **u_in_cumsum**: sum of air input to the lung
# - **u_in_lag1**: input flow just one step before
# - **u_out_lag1**: output valve (open or close) just one step before
# - **u_in_lag2**: input flow just two step before
# - **u_out_lag2**: output flow (open or close) just two step before
# - **u_in_lag_back1**: looks one step ahead inside same breath
# - **u_out_lag_back1**: output valve (open or close) one step in future
# - **u_in_lag_back2**: looks two step ahead inside same breath
# - **u_out_lag_back2**: output valve (open or close) two step in future

# %%
def add_breath_features(df):


    df['u_in_cumsum'] = df.groupby('breath_id')['u_in'].cumsum()


    df['u_in_lag1'] = df.groupby('breath_id')['u_in'].shift(1)
    df['u_out_lag1'] = df.groupby('breath_id')['u_out'].shift(1)

    df['u_in_lag2'] = df.groupby('breath_id')['u_in'].shift(2)
    df['u_out_lag2'] = df.groupby('breath_id')['u_out'].shift(2)


    df['u_in_lag_back1'] = df.groupby('breath_id')['u_in'].shift(-1)
    df['u_out_lag_back1'] = df.groupby('breath_id')['u_out'].shift(-1)

    df['u_in_lag_back2'] = df.groupby('breath_id')['u_in'].shift(-2)
    df['u_out_lag_back2'] = df.groupby('breath_id')['u_out'].shift(-2)

    return df

# %%
train_df = add_breath_features(train_df)
test_df  = add_breath_features(test_df)

# %% [markdown]
# One hot Encoding R and C features

# %%
train_df = pd.get_dummies(train_df, columns=["R","C"])
test_df  = pd.get_dummies(test_df,  columns=["R","C"])

# %%
train_df
# Out:
#               id  breath_id  time_step       u_in  u_out   pressure  \
# 0              1          1   0.000000   0.083334      0   5.837492
# 1              2          1   0.033652  18.383041      0   5.907794
# 2              3          1   0.067514  22.509278      0   7.876254
# 3              4          1   0.101542  22.808822      0  11.742872
# 4              5          1   0.135756  25.355850      0  12.234987
# ...          ...        ...        ...        ...    ...        ...
# 6035995  6035996     125749   2.504603   1.489714      1   3.869032
# 6035996  6035997     125749   2.537961   1.488497      1   3.869032
# 6035997  6035998     125749   2.571408   1.558978      1   3.798729
# 6035998  6035999     125749   2.604744   1.272663      1   4.079938
# 6035999  6036000     125749   2.638017   1.482739      1   3.869032
#
#          u_in_cumsum  u_in_lag1  u_out_lag1  u_in_lag2  ...  u_in_lag_back1  \
# 0           0.083334        NaN         NaN        NaN  ...       18.383041
# 1          18.466375   0.083334         0.0        NaN  ...       22.509278
# 2          40.975653  18.383041         0.0   0.083334  ...       22.808822
# 3          63.784476  22.509278         0.0  18.383041  ...       25.355850
# 4          89.140326  22.808822         0.0  22.509278  ...       27.259866
# ...              ...        ...         ...        ...  ...             ...
# 6035995   387.109297   1.420711         1.0   1.353205  ...        1.488497
# 6035996   388.597794   1.489714         1.0   1.420711  ...        1.558978
# 6035997   390.156772   1.488497         1.0   1.489714  ...        1.272663
# 6035998   391.429435   1.558978         1.0   1.488497  ...        1.482739
# 6035999   392.912174   1.272663         1.0   1.558978  ...             NaN
#
#          u_out_lag_back1  u_in_lag_back2  u_out_lag_back2    R_5   R_20  \
# 0                    0.0       22.509278              0.0  False   True
# 1                    0.0       22.808822              0.0  False   True
# 2                    0.0       25.355850              0.0  False   True
# 3                    0.0       27.259866              0.0  False   True
# 4                    0.0       27.127486              0.0  False   True
# ...                  ...             ...              ...    ...    ...
# 6035995              1.0        1.558978              1.0  False  False
# 6035996              1.0        1.272663              1.0  False  False
# 6035997              1.0        1.482739              1.0  False  False
# 6035998              1.0             NaN              NaN  False  False
# 6035999              NaN             NaN              NaN  False  False
#
#           R_50   C_10   C_20   C_50
# 0        False  False  False   True
# 1        False  False  False   True
# 2        False  False  False   True
# 3        False  False  False   True
# 4        False  False  False   True
# ...        ...    ...    ...    ...
# 6035995   True   True  False  False
# 6035996   True   True  False  False
# 6035997   True   True  False  False
# 6035998   True   True  False  False
# 6035999   True   True  False  False
#
# [6036000 rows x 21 columns]

# %%
train_df = train_df.fillna(0)
test_df  = test_df.fillna(0)

# %%
numeric_cols = [
    "time_step", "u_in",
    "u_in_cumsum",
    "u_in_lag1", "u_out_lag1",
    "u_in_lag2", "u_out_lag2",
    "u_in_lag_back1", "u_out_lag_back1",
    "u_in_lag_back2", "u_out_lag_back2"
]

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %% [markdown]
# Data Standarization

# %%
scaler = StandardScaler()
train_df[numeric_cols] = scaler.fit_transform(train_df[numeric_cols])
test_df[numeric_cols]  = scaler.transform(test_df[numeric_cols])

# %%
feature_cols = [c for c in train_df.columns if c not in ["id","pressure","breath_id"]]

# %% [markdown]
# Grouping of each breath into a sequence and converting to numpy array

# %%
X = train_df.groupby("breath_id")[feature_cols].apply(
        lambda x: x.to_numpy(dtype=np.float32)
    ).to_list()
y = train_df.groupby("breath_id")["pressure"].apply(
        lambda x: x.to_numpy(dtype=np.float32)
    ).to_list()
X_test = test_df.groupby("breath_id")[feature_cols].apply(
            lambda x: x.to_numpy(dtype=np.float32)
        ).to_list()


X = np.array(X)
y = np.array(y)
X_test = np.array(X_test)

# %% [markdown]
# Dividing train datasets into two parts.
# - **Training**: 90 %
# - **Validation**: 10%

# %%
X_train, X_val, y_train, y_val = train_test_split(
    X, y, test_size=0.1, random_state=42
)

# %% [markdown]
# Dataset class to communicate with Data loader

# %%
class VentilatorDataset(Dataset):
    def __init__(self, X, y=None):
        self.X = torch.tensor(X, dtype=torch.float32)
        self.y = None if y is None else torch.tensor(y, dtype=torch.float32)
    def __len__(self):
        return len(self.X)
    def __getitem__(self, idx):
        if self.y is None:
            return self.X[idx]
        return self.X[idx], self.y[idx]

# DataLoader - to load training, validation, and testing data
train_loader = DataLoader(VentilatorDataset(X_train, y_train), batch_size=64, shuffle=True)
val_loader   = DataLoader(VentilatorDataset(X_val,   y_val),   batch_size=64)
test_loader  = DataLoader(VentilatorDataset(X_test), batch_size=64)

# %% [markdown]
# RNN for 450 epochs

# %%
class SimpleRNN(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, dropout):
        super().__init__()
        self.rnn = nn.RNN(
            input_size=input_size,
            hidden_size=hidden_size,
            num_layers=num_layers,
            dropout=dropout if num_layers > 1 else 0.0,
            batch_first=True
        )
        self.fc = nn.Linear(hidden_size, 1)

    def forward(self, x):
        out, _ = self.rnn(x)
        return self.fc(out).squeeze(-1)

criterion = nn.L1Loss()
input_size = len(feature_cols)

# %%
print(input_size)
# Out:
# 18

# %%
import random

# %% [markdown]
# Random choice of the hyperparameters to tune from

# %%
def sample_params():
    return {
        "hidden_size": random.choice([64, 128, 192]),
        "num_layers": random.choice([1, 2, 3]),
        "dropout": random.uniform(0.0, 0.4),
        "lr": 10 ** random.uniform(-4, -2)   # log-uniform LR
    }

# %%
N_TRIALS = 10
EPOCHS = 8

best_val_mae = float("inf")
best_params = None
best_state = None
results = []

# %% [markdown]
# Trials to get the best hyperparameter, selecting the the one that gets low validation MAE

# %%
for trial in range(N_TRIALS):
    print(f"\nRandom Search: {trial+1}/{N_TRIALS}")
    params = sample_params()
    hs, nl, dp, lr = params["hidden_size"], params["num_layers"], params["dropout"], params["lr"]
    print("Sampled Params:", params)

    model = SimpleRNN(input_size, hs, nl, dp).to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode="min")

    train_hist = []
    val_hist = []

    for epoch in range(EPOCHS):
        model.train()
        train_loss = 0

        for Xb, yb in train_loader:
            Xb, yb = Xb.to(device), yb.to(device)

            optimizer.zero_grad()
            pred = model(Xb)
            loss = criterion(pred, yb)
            loss.backward()
            optimizer.step()
            train_loss += loss.item()

        train_loss /= len(train_loader)
        train_hist.append(train_loss)

        # Validation
        model.eval()
        val_loss = 0
        with torch.no_grad():
            for Xb, yb in val_loader:
                Xb, yb = Xb.to(device), yb.to(device)
                val_loss += criterion(model(Xb), yb).item()

        val_loss /= len(val_loader)
        val_hist.append(val_loss)

        scheduler.step(val_loss)

        print(f"Epoch {epoch+1}/{EPOCHS} | Train MAE={train_loss:.5f}, Val MAE={val_loss:.5f}")

    results.append((val_loss, params, train_hist, val_hist))

    if val_loss < best_val_mae:
        best_val_mae = val_loss
        best_params = params
        best_state = model.state_dict().copy()
        print("New BEST model found!")
# Out:
# Random Search: 1/10
# Sampled Params: {'hidden_size': 192, 'num_layers': 2, 'dropout': 0.32058407165003855, 'lr': 0.00015120180436594834}
# Epoch 1/8 | Train MAE=3.40417, Val MAE=2.04729
# Epoch 2/8 | Train MAE=1.48567, Val MAE=1.35270
# Epoch 3/8 | Train MAE=1.14718, Val MAE=1.03738
# Epoch 4/8 | Train MAE=1.02336, Val MAE=1.10697
# Epoch 5/8 | Train MAE=0.95987, Val MAE=0.97025
# Epoch 6/8 | Train MAE=0.91455, Val MAE=0.87330
# Epoch 7/8 | Train MAE=0.89159, Val MAE=0.86786
# Epoch 8/8 | Train MAE=0.85998, Val MAE=0.88927
# New BEST model found!
#
# Random Search: 2/10
# Sampled Params: {'hidden_size': 64, 'num_layers': 3, 'dropout': 0.16847725037293879, 'lr': 0.0008579562654050306}
# Epoch 1/8 | Train MAE=3.29323, Val MAE=1.49529
# Epoch 2/8 | Train MAE=1.17531, Val MAE=1.17200
# Epoch 3/8 | Train MAE=1.00199, Val MAE=1.01891
# Epoch 4/8 | Train MAE=0.93410, Val MAE=0.85702
# Epoch 5/8 | Train MAE=0.88562, Val MAE=0.88308
# Epoch 6/8 | Train MAE=0.85625, Val MAE=0.83577
# Epoch 7/8 | Train MAE=0.83165, Val MAE=0.80804
# Epoch 8/8 | Train MAE=0.81469, Val MAE=0.85556
# New BEST model found!
#
# Random Search: 3/10
# Sampled Params: {'hidden_size': 192, 'num_layers': 1, 'dropout': 0.31372440502153354, 'lr': 0.00012262323717802812}
# Epoch 1/8 | Train MAE=4.18991, Val MAE=2.92549
# Epoch 2/8 | Train MAE=2.80384, Val MAE=2.45973
# Epoch 3/8 | Train MAE=2.46475, Val MAE=2.05841
# Epoch 4/8 | Train MAE=1.91899, Val MAE=1.92179
# Epoch 5/8 | Train MAE=1.49727, Val MAE=1.35239
# Epoch 6/8 | Train MAE=1.29180, Val MAE=1.23379
# Epoch 7/8 | Train MAE=1.18303, Val MAE=1.40115
# Epoch 8/8 | Train MAE=1.11116, Val MAE=1.06007
#
# Random Search: 4/10
# Sampled Params: {'hidden_size': 128, 'num_layers': 3, 'dropout': 0.2913962538294296, 'lr': 0.00015372104133803052}
# Epoch 1/8 | Train MAE=4.09417, Val MAE=2.66817
# Epoch 2/8 | Train MAE=1.95400, Val MAE=1.45156
# Epoch 3/8 | Train MAE=1.28152, Val MAE=1.05079
# Epoch 4/8 | Train MAE=1.07192, Val MAE=1.08096
# Epoch 5/8 | Train MAE=0.99415, Val MAE=0.92244
# Epoch 6/8 | Train MAE=0.95135, Val MAE=0.87275
# Epoch 7/8 | Train MAE=0.92378, Val MAE=0.88884
# Epoch 8/8 | Train MAE=0.90091, Val MAE=0.91988
#
# Random Search: 5/10
# Sampled Params: {'hidden_size': 64, 'num_layers': 1, 'dropout': 0.07634520628123105, 'lr': 0.0018176063379620128}
# Epoch 1/8 | Train MAE=2.33992, Val MAE=1.11574
# Epoch 2/8 | Train MAE=1.01516, Val MAE=1.25117
# Epoch 3/8 | Train MAE=0.91432, Val MAE=1.51687
# Epoch 4/8 | Train MAE=0.91291, Val MAE=0.95487
# Epoch 5/8 | Train MAE=0.83607, Val MAE=1.29283
# Epoch 6/8 | Train MAE=0.82427, Val MAE=0.83613
# Epoch 7/8 | Train MAE=0.79660, Val MAE=1.07751
# Epoch 8/8 | Train MAE=0.78778, Val MAE=0.89350
#
# Random Search: 6/10
# Sampled Params: {'hidden_size': 128, 'num_layers': 2, 'dropout': 0.1636366113376203, 'lr': 0.00012899410985834985}
# Epoch 1/8 | Train MAE=4.36180, Val MAE=3.18787
# Epoch 2/8 | Train MAE=2.31603, Val MAE=2.04365
# Epoch 3/8 | Train MAE=1.56475, Val MAE=1.33603
# Epoch 4/8 | Train MAE=1.24252, Val MAE=1.16602
# Epoch 5/8 | Train MAE=1.09980, Val MAE=0.99781
# Epoch 6/8 | Train MAE=1.00523, Val MAE=0.95187
# Epoch 7/8 | Train MAE=0.95794, Val MAE=1.12804
# Epoch 8/8 | Train MAE=0.92932, Val MAE=0.94738
#
# Random Search: 7/10
# Sampled Params: {'hidden_size': 64, 'num_layers': 2, 'dropout': 0.3403007846981592, 'lr': 0.000650494048247214}
# Epoch 1/8 | Train MAE=3.49565, Val MAE=1.55984
# Epoch 2/8 | Train MAE=1.26816, Val MAE=1.07445
# Epoch 3/8 | Train MAE=1.03073, Val MAE=0.99782
# Epoch 4/8 | Train MAE=0.96493, Val MAE=1.27543
# Epoch 5/8 | Train MAE=0.93270, Val MAE=0.88544
# Epoch 6/8 | Train MAE=0.89838, Val MAE=0.92808
# Epoch 7/8 | Train MAE=0.87712, Val MAE=1.02373
# Epoch 8/8 | Train MAE=0.86697, Val MAE=0.79911
# New BEST model found!
#
# Random Search: 8/10
# Sampled Params: {'hidden_size': 128, 'num_layers': 2, 'dropout': 0.31197513087456336, 'lr': 0.0005415176126247108}
# Epoch 1/8 | Train MAE=3.26507, Val MAE=1.77011
# Epoch 2/8 | Train MAE=1.43421, Val MAE=1.16313
# Epoch 3/8 | Train MAE=1.11577, Val MAE=1.00200
# Epoch 4/8 | Train MAE=1.01154, Val MAE=1.45444
# Epoch 5/8 | Train MAE=0.96102, Val MAE=0.85020
# Epoch 6/8 | Train MAE=0.91535, Val MAE=0.85111
# Epoch 7/8 | Train MAE=0.87674, Val MAE=1.07413
# Epoch 8/8 | Train MAE=0.85330, Val MAE=0.80955
#
# Random Search: 9/10
# Sampled Params: {'hidden_size': 64, 'num_layers': 3, 'dropout': 0.31188460898070103, 'lr': 0.0041561334307543135}
# Epoch 1/8 | Train MAE=3.27363, Val MAE=1.69022
# Epoch 2/8 | Train MAE=1.46002, Val MAE=1.29238
# Epoch 3/8 | Train MAE=1.48817, Val MAE=1.59747
# Epoch 4/8 | Train MAE=1.67799, Val MAE=1.46129
# Epoch 5/8 | Train MAE=1.80067, Val MAE=1.49623
# Epoch 6/8 | Train MAE=1.56657, Val MAE=1.62917
# Epoch 7/8 | Train MAE=1.96048, Val MAE=1.73870
# Epoch 8/8 | Train MAE=2.02538, Val MAE=1.69959
#
# Random Search: 10/10
# Sampled Params: {'hidden_size': 128, 'num_layers': 2, 'dropout': 0.023487013573205484, 'lr': 0.00013545824001246626}
# Epoch 1/8 | Train MAE=4.28119, Val MAE=2.75957
# Epoch 2/8 | Train MAE=1.99822, Val MAE=1.63161
# Epoch 3/8 | Train MAE=1.31554, Val MAE=1.18114
# Epoch 4/8 | Train MAE=1.12135, Val MAE=1.25788
# Epoch 5/8 | Train MAE=1.02377, Val MAE=1.23660
# Epoch 6/8 | Train MAE=0.95943, Val MAE=1.13886
# Epoch 7/8 | Train MAE=0.92143, Val MAE=0.93471
# Epoch 8/8 | Train MAE=0.89688, Val MAE=0.97796

# %%
print("\nBest MAE:", best_val_mae)
print("Best Params:", best_params)
# Out:
# Best MAE: 0.7991134332398236
# Best Params: {'hidden_size': 64, 'num_layers': 2, 'dropout': 0.3403007846981592, 'lr': 0.000650494048247214}

# %% [markdown]
# Training with the Best Hyperparameters
# - Training till 450 epochs
# - Adam opitmizer

# %%
hs, nl, dp, lr = best_params.values()

final_model = SimpleRNN(input_size, hs, nl, dp).to(device)
optimizer = torch.optim.Adam(final_model.parameters(), lr=lr)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode="min")

FINAL_EPOCHS = 450
final_train_hist = []
final_val_hist = []

for epoch in range(FINAL_EPOCHS):
    final_model.train()
    train_loss = 0

    for Xb, yb in train_loader:
        Xb, yb = Xb.to(device), yb.to(device)
        optimizer.zero_grad()
        pred = final_model(Xb)
        loss = criterion(pred, yb)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()

    train_loss /= len(train_loader)
    final_train_hist.append(train_loss)

    final_model.eval()
    val_loss = 0
    with torch.no_grad():
        for Xb, yb in val_loader:
            Xb, yb = Xb.to(device), yb.to(device)
            val_loss += criterion(final_model(Xb), yb).item()

    val_loss /= len(val_loader)
    final_val_hist.append(val_loss)

    scheduler.step(val_loss)

    print(f"[FINAL] Epoch {epoch+1}/{FINAL_EPOCHS} | Train MAE={train_loss:.5f}, Val MAE={val_loss:.5f}")
# Out:
# [FINAL] Epoch 1/450 | Train MAE=3.55935, Val MAE=1.65868
# [FINAL] Epoch 2/450 | Train MAE=1.29367, Val MAE=1.18170
# [FINAL] Epoch 3/450 | Train MAE=1.04986, Val MAE=0.94313
# [FINAL] Epoch 4/450 | Train MAE=0.97258, Val MAE=1.13424
# [FINAL] Epoch 5/450 | Train MAE=0.93589, Val MAE=0.92800
# [FINAL] Epoch 6/450 | Train MAE=0.89309, Val MAE=0.96211
# [FINAL] Epoch 7/450 | Train MAE=0.87946, Val MAE=0.90754
# [FINAL] Epoch 8/450 | Train MAE=0.84809, Val MAE=0.98190
# [FINAL] Epoch 9/450 | Train MAE=0.83650, Val MAE=0.87017
# [FINAL] Epoch 10/450 | Train MAE=0.81878, Val MAE=0.75882
# [FINAL] Epoch 11/450 | Train MAE=0.80684, Val MAE=0.82925
# [FINAL] Epoch 12/450 | Train MAE=0.79760, Val MAE=0.85425
# [FINAL] Epoch 13/450 | Train MAE=0.78770, Val MAE=0.83558
# [FINAL] Epoch 14/450 | Train MAE=0.78155, Val MAE=0.76589
# [FINAL] Epoch 15/450 | Train MAE=0.76955, Val MAE=0.89303
# [FINAL] Epoch 16/450 | Train MAE=0.76677, Val MAE=0.69730
# [FINAL] Epoch 17/450 | Train MAE=0.75859, Val MAE=0.76537
# [FINAL] Epoch 18/450 | Train MAE=0.75894, Val MAE=0.71455
# [FINAL] Epoch 19/450 | Train MAE=0.75028, Val MAE=0.77893
# [FINAL] Epoch 20/450 | Train MAE=0.74390, Val MAE=0.72438
# [FINAL] Epoch 21/450 | Train MAE=0.73356, Val MAE=0.68895
# [FINAL] Epoch 22/450 | Train MAE=0.73118, Val MAE=0.77717
# [FINAL] Epoch 23/450 | Train MAE=0.73367, Val MAE=0.70382
# [FINAL] Epoch 24/450 | Train MAE=0.72085, Val MAE=0.70302
# [FINAL] Epoch 25/450 | Train MAE=0.71575, Val MAE=0.68455
# [FINAL] Epoch 26/450 | Train MAE=0.71172, Val MAE=0.68590
# [FINAL] Epoch 27/450 | Train MAE=0.70228, Val MAE=0.65856
# [FINAL] Epoch 28/450 | Train MAE=0.70216, Val MAE=0.73500
# [FINAL] Epoch 425/450 | Train MAE=0.56742, Val MAE=0.53383
# [FINAL] Epoch 426/450 | Train MAE=0.56740, Val MAE=0.53383
# [FINAL] Epoch 427/450 | Train MAE=0.56743, Val MAE=0.53383
# [FINAL] Epoch 428/450 | Train MAE=0.56771, Val MAE=0.53383
# [FINAL] Epoch 429/450 | Train MAE=0.56737, Val MAE=0.53383
# [FINAL] Epoch 430/450 | Train MAE=0.56736, Val MAE=0.53383
# [FINAL] Epoch 431/450 | Train MAE=0.56737, Val MAE=0.53383
# [FINAL] Epoch 432/450 | Train MAE=0.56748, Val MAE=0.53383
# [FINAL] Epoch 433/450 | Train MAE=0.56755, Val MAE=0.53383
# [FINAL] Epoch 434/450 | Train MAE=0.56741, Val MAE=0.53383
# [FINAL] Epoch 435/450 | Train MAE=0.56758, Val MAE=0.53383
# [FINAL] Epoch 436/450 | Train MAE=0.56697, Val MAE=0.53383
# [FINAL] Epoch 437/450 | Train MAE=0.56686, Val MAE=0.53383
# [FINAL] Epoch 438/450 | Train MAE=0.56674, Val MAE=0.53383
# [FINAL] Epoch 439/450 | Train MAE=0.56716, Val MAE=0.53383
# [FINAL] Epoch 440/450 | Train MAE=0.56719, Val MAE=0.53383
# [FINAL] Epoch 441/450 | Train MAE=0.56672, Val MAE=0.53383
# [FINAL] Epoch 442/450 | Train MAE=0.56773, Val MAE=0.53383
# [FINAL] Epoch 443/450 | Train MAE=0.56726, Val MAE=0.53383
# [FINAL] Epoch 444/450 | Train MAE=0.56730, Val MAE=0.53383
# [FINAL] Epoch 445/450 | Train MAE=0.56725, Val MAE=0.53383
# [FINAL] Epoch 446/450 | Train MAE=0.56749, Val MAE=0.53383
# [FINAL] Epoch 447/450 | Train MAE=0.56693, Val MAE=0.53383
# [FINAL] Epoch 448/450 | Train MAE=0.56731, Val MAE=0.53383
# [FINAL] Epoch 449/450 | Train MAE=0.56746, Val MAE=0.53383
# [FINAL] Epoch 450/450 | Train MAE=0.56700, Val MAE=0.53383

# %% [markdown]
# Visualization of Train MAE and Val MAE

# %%
plt.figure(figsize=(8,5))
plt.plot(final_train_hist, label="Train MAE")
plt.plot(final_val_hist, label="Validation MAE")
plt.xlabel("Epoch")
plt.ylabel("MAE")
plt.title("Training vs Validation MAE (RNN)")
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# Testing of Trained RNN on test data. <br>
#
# -Collection of prediction

# %%
preds = []
final_model.eval()

with torch.no_grad():
    for Xb in test_loader:
        Xb = Xb.to(device)
        pred = final_model(Xb)
        preds.append(pred.cpu().numpy())

preds = np.concatenate(preds).reshape(-1)
print("Test predictions shape:", preds.shape)
# Out:
# Test predictions shape: (4024000,)

# %% [markdown]
# Kaggle Submission requires the predictions to be in .csv format. <br>
# With two columns **ID** and **prediction** columns

# %%
submission = pd.DataFrame({
    "id": test_df["id"],
    "pressure": preds
})

# %%
submission.to_csv("RNN_submission_differentfeatures.csv", index=False)
print("Saved submission.csv")
submission.head()
# Out:
# Saved submission.csv
#    id  pressure
# 0   1  6.178802
# 1   2  5.984040
# 2   3  6.807320
# 3   4  7.860802
# 4   5  8.851669
