# %% [markdown]
# RNN- Without Additional Features Engineered from the datasets

# %%
# !pip install opendatasets --quiet

# %%
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# %%
import opendatasets as od
od.download("https://www.kaggle.com/competitions/ventilator-pressure-prediction/data?select=train.csv")
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: sulovebhattarai
# Your Kaggle Key: ··········
# Downloading ventilator-pressure-prediction.zip to ./ventilator-pressure-prediction
# 100%|██████████| 223M/223M [00:00<00:00, 1.01GB/s]
# Extracting archive ./ventilator-pressure-prediction/ventilator-pressure-prediction.zip to ./ventilator-pressure-prediction

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %% [markdown]
# Load Train and Test Datasets

# %%
train_df = pd.read_csv("/content/ventilator-pressure-prediction/train.csv")
test_df= pd.read_csv("/content/ventilator-pressure-prediction/test.csv")

# %% [markdown]
# One hot Encoding R and C features

# %%
train_df = pd.get_dummies(train_df, columns=["R","C"])
test_df  = pd.get_dummies(test_df,  columns=["R","C"])

# %% [markdown]
# Data Standarization

# %%
numeric_cols = ["time_step", "u_in"]
scaler = StandardScaler()

train_df[numeric_cols] = scaler.fit_transform(train_df[numeric_cols])
test_df[numeric_cols]  = scaler.transform(test_df[numeric_cols])

# %%
feature_cols = [c for c in train_df.columns if c not in ["id","pressure","breath_id"]]

# %% [markdown]
# Grouping of each breath into a sequence and converting to numpy array

# %%
X = train_df.groupby("breath_id")[feature_cols].apply(
        lambda x: x.to_numpy(dtype=np.float32)
    ).to_list()

y = train_df.groupby("breath_id")["pressure"].apply(
        lambda x: x.to_numpy(dtype=np.float32)
    ).to_list()

# Test sequences
X_test = test_df.groupby("breath_id")[feature_cols].apply(
            lambda x: x.to_numpy(dtype=np.float32)
        ).to_list()

X = np.array(X)
y = np.array(y)
X_test = np.array(X_test)

# %% [markdown]
# Dividing train datasets into two parts.
#
# -Training: 90 %
# -Validation: 10%

# %%
X_train, X_val, y_train, y_val = train_test_split(
    X, y, test_size=0.1, random_state=42
)

# %% [markdown]
# Dataset class to communicate with Data loader

# %%
class VentilatorDataset(Dataset):
    def __init__(self, X, y=None):
        self.X = torch.tensor(X, dtype=torch.float32)
        self.y = None if y is None else torch.tensor(y, dtype=torch.float32)

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        if self.y is None:
            return self.X[idx]
        return self.X[idx], self.y[idx]

# %% [markdown]
# DataLoader - to load training, validation, and testing data

# %%
train_loader = DataLoader(VentilatorDataset(X_train, y_train), batch_size=64, shuffle=True)
val_loader   = DataLoader(VentilatorDataset(X_val,   y_val),   batch_size=64)
test_loader  = DataLoader(VentilatorDataset(X_test), batch_size=64)

# %% [markdown]
# LSTM

# %%
class SimpleLSTM(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, dropout):
        super().__init__()

        self.lstm = nn.LSTM(
            input_size=input_size,
            hidden_size=hidden_size,
            num_layers=num_layers,
            dropout=dropout if num_layers > 1 else 0.0,
            batch_first=True
        )
        self.fc = nn.Linear(hidden_size, 1)

    def forward(self, x):
        out, _ = self.lstm(x)
        out = self.fc(out).squeeze(-1)
        return out


input_size = len(feature_cols)
criterion = nn.L1Loss()

# %%
import random

# %% [markdown]
# Random choice of the hyperparameters to tune from

# %%
def sample_params():
    return {
        "hidden_size": random.choice([64, 128, 192]),
        "num_layers": random.choice([1, 2, 3]),
        "dropout": random.uniform(0.0, 0.4),
        "lr": 10 ** random.uniform(-4, -2)   # log-uniform LR
    }

# %%
N_TRIALS = 10
EPOCHS = 8

best_val_mae = float("inf")
best_params = None
best_state = None
results = []

# %% [markdown]
# Trials to get the best hyperparameter, selecting the the one that gets low validation MAE

# %%
for trial in range(N_TRIALS):
    print(f"\nRandom Trial {trial+1}/{N_TRIALS} ")
    params = sample_params()
    hs, nl, dp, lr = params["hidden_size"], params["num_layers"], params["dropout"], params["lr"]
    print("Sampled Params:", params)

    # Build model
    model = SimpleLSTM(input_size, hs, nl, dp).to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode="min")

    train_hist = []
    val_hist = []

    for epoch in range(EPOCHS):
        model.train()
        train_loss = 0

        for Xb, yb in train_loader:
            Xb, yb = Xb.to(device), yb.to(device)

            optimizer.zero_grad()
            pred = model(Xb)
            loss = criterion(pred, yb)
            loss.backward()
            optimizer.step()
            train_loss += loss.item()

        train_loss /= len(train_loader)
        train_hist.append(train_loss)

        # Validation
        model.eval()
        val_loss = 0
        with torch.no_grad():
            for Xb, yb in val_loader:
                Xb, yb = Xb.to(device), yb.to(device)
                val_loss += criterion(model(Xb), yb).item()

        val_loss /= len(val_loader)
        val_hist.append(val_loss)

        scheduler.step(val_loss)

        print(f"Epoch {epoch+1}/{EPOCHS} | Train MAE={train_loss:.5f}, Val MAE={val_loss:.5f}")

    results.append((val_loss, params, train_hist, val_hist))

    if val_loss < best_val_mae:
        best_val_mae = val_loss
        best_params = params
        best_state = model.state_dict().copy()
        print("New BEST model found!")
# Out:
# Random Trial 1/10
# Sampled Params: {'hidden_size': 192, 'num_layers': 3, 'dropout': 0.3758464569242461, 'lr': 0.0028437228538019644}
# Epoch 1/8 | Train MAE=1.96527, Val MAE=1.09742
# Epoch 2/8 | Train MAE=0.79105, Val MAE=0.67403
# Epoch 3/8 | Train MAE=0.70747, Val MAE=1.01178
# Epoch 4/8 | Train MAE=0.69562, Val MAE=0.75821
# Epoch 5/8 | Train MAE=0.63839, Val MAE=0.79739
# Epoch 6/8 | Train MAE=0.62802, Val MAE=0.61016
# Epoch 7/8 | Train MAE=0.59181, Val MAE=0.57136
# Epoch 8/8 | Train MAE=0.57351, Val MAE=0.59148
# New BEST model found!
#
# Random Trial 2/10
# Sampled Params: {'hidden_size': 192, 'num_layers': 2, 'dropout': 0.19605154937100058, 'lr': 0.0019398356874841902}
# Epoch 1/8 | Train MAE=1.98256, Val MAE=2.45846
# Epoch 2/8 | Train MAE=0.94650, Val MAE=1.02655
# Epoch 3/8 | Train MAE=0.74713, Val MAE=0.66850
# Epoch 4/8 | Train MAE=0.68645, Val MAE=0.95722
# Epoch 5/8 | Train MAE=0.65694, Val MAE=0.63543
# Epoch 6/8 | Train MAE=0.62730, Val MAE=0.62251
# Epoch 7/8 | Train MAE=0.60619, Val MAE=0.57055
# Epoch 8/8 | Train MAE=0.58556, Val MAE=0.57658
# New BEST model found!
#
# Random Trial 3/10
# Sampled Params: {'hidden_size': 192, 'num_layers': 1, 'dropout': 0.2853022170533635, 'lr': 0.008760266945960894}
# Epoch 1/8 | Train MAE=1.58418, Val MAE=0.95640
# Epoch 2/8 | Train MAE=0.78610, Val MAE=0.85697
# Epoch 3/8 | Train MAE=0.71004, Val MAE=1.09959
# Epoch 4/8 | Train MAE=0.68926, Val MAE=0.82757
# Epoch 5/8 | Train MAE=0.66227, Val MAE=0.73938
# Epoch 6/8 | Train MAE=0.63318, Val MAE=0.70735
# Epoch 7/8 | Train MAE=0.63153, Val MAE=0.69927
# Epoch 8/8 | Train MAE=0.61918, Val MAE=0.86078
#
# Random Trial 4/10
# Sampled Params: {'hidden_size': 192, 'num_layers': 3, 'dropout': 0.16019909545442781, 'lr': 0.005802704788214549}
# Epoch 1/8 | Train MAE=1.86634, Val MAE=1.05863
# Epoch 2/8 | Train MAE=0.87642, Val MAE=0.96450
# Epoch 3/8 | Train MAE=0.76543, Val MAE=0.94675
# Epoch 4/8 | Train MAE=0.72928, Val MAE=0.91939
# Epoch 5/8 | Train MAE=0.69397, Val MAE=0.64528
# Epoch 6/8 | Train MAE=0.66163, Val MAE=0.69146
# Epoch 7/8 | Train MAE=0.64650, Val MAE=0.62793
# Epoch 8/8 | Train MAE=0.62871, Val MAE=0.74346
#
# Random Trial 5/10
# Sampled Params: {'hidden_size': 192, 'num_layers': 3, 'dropout': 0.28423306507180734, 'lr': 0.0002811933203158755}
# Epoch 1/8 | Train MAE=3.12265, Val MAE=1.89240
# Epoch 2/8 | Train MAE=1.22541, Val MAE=1.03281
# Epoch 3/8 | Train MAE=1.01318, Val MAE=1.08093
# Epoch 4/8 | Train MAE=0.91885, Val MAE=1.21953
# Epoch 5/8 | Train MAE=0.85426, Val MAE=0.80633
# Epoch 6/8 | Train MAE=0.80535, Val MAE=0.81827
# Epoch 7/8 | Train MAE=0.77371, Val MAE=0.72735
# Epoch 8/8 | Train MAE=0.74277, Val MAE=0.75095
#
# Random Trial 6/10
# Sampled Params: {'hidden_size': 192, 'num_layers': 3, 'dropout': 0.03261822877643579, 'lr': 0.00011586983176285439}
# Epoch 1/8 | Train MAE=4.02109, Val MAE=2.10124
# Epoch 2/8 | Train MAE=1.54777, Val MAE=1.50528
# Epoch 3/8 | Train MAE=1.17600, Val MAE=1.21346
# Epoch 4/8 | Train MAE=1.06425, Val MAE=1.07281
# Epoch 5/8 | Train MAE=0.99194, Val MAE=0.92443
# Epoch 6/8 | Train MAE=0.93924, Val MAE=0.92623
# Epoch 7/8 | Train MAE=0.89117, Val MAE=0.85164
# Epoch 8/8 | Train MAE=0.85334, Val MAE=0.80598
#
# Random Trial 7/10
# Sampled Params: {'hidden_size': 64, 'num_layers': 1, 'dropout': 0.23643021695601096, 'lr': 0.0009821879403389745}
# Epoch 1/8 | Train MAE=3.10378, Val MAE=1.40321
# Epoch 2/8 | Train MAE=1.11984, Val MAE=1.02120
# Epoch 3/8 | Train MAE=0.90472, Val MAE=0.88501
# Epoch 4/8 | Train MAE=0.82122, Val MAE=0.91995
# Epoch 5/8 | Train MAE=0.77423, Val MAE=0.89920
# Epoch 6/8 | Train MAE=0.74678, Val MAE=0.73911
# Epoch 7/8 | Train MAE=0.72186, Val MAE=0.78880
# Epoch 8/8 | Train MAE=0.70405, Val MAE=0.68076
#
# Random Trial 8/10
# Sampled Params: {'hidden_size': 128, 'num_layers': 3, 'dropout': 0.15912787699143688, 'lr': 0.0056709532567520435}
# Epoch 1/8 | Train MAE=2.34841, Val MAE=1.16444
# Epoch 2/8 | Train MAE=0.87110, Val MAE=1.20983
# Epoch 3/8 | Train MAE=0.72559, Val MAE=0.97792
# Epoch 4/8 | Train MAE=0.67530, Val MAE=0.77577
# Epoch 5/8 | Train MAE=0.63986, Val MAE=0.71682
# Epoch 6/8 | Train MAE=0.61301, Val MAE=0.58533
# Epoch 7/8 | Train MAE=0.59548, Val MAE=0.73475
# Epoch 8/8 | Train MAE=0.58199, Val MAE=0.64780
#
# Random Trial 9/10
# Sampled Params: {'hidden_size': 128, 'num_layers': 1, 'dropout': 0.2484802589262509, 'lr': 0.00859661429753428}
# Epoch 1/8 | Train MAE=1.55690, Val MAE=1.73474
# Epoch 2/8 | Train MAE=0.80337, Val MAE=0.85388
# Epoch 3/8 | Train MAE=0.71444, Val MAE=0.76891
# Epoch 4/8 | Train MAE=0.67432, Val MAE=0.66518
# Epoch 5/8 | Train MAE=0.64838, Val MAE=0.99430
# Epoch 6/8 | Train MAE=0.65821, Val MAE=0.66992
# Epoch 7/8 | Train MAE=0.61873, Val MAE=0.60287
# Epoch 8/8 | Train MAE=0.61012, Val MAE=0.58374
#
# Random Trial 10/10
# Sampled Params: {'hidden_size': 64, 'num_layers': 2, 'dropout': 0.2620088880481317, 'lr': 0.00010469285998828034}
# Epoch 1/8 | Train MAE=6.05994, Val MAE=5.13441
# Epoch 2/8 | Train MAE=5.12798, Val MAE=5.09291
# Epoch 3/8 | Train MAE=4.95245, Val MAE=3.93529
# Epoch 4/8 | Train MAE=3.13745, Val MAE=2.40791
# Epoch 5/8 | Train MAE=2.01642, Val MAE=1.66730
# Epoch 6/8 | Train MAE=1.50304, Val MAE=1.49287
# Epoch 7/8 | Train MAE=1.28559, Val MAE=1.24858
# Epoch 8/8 | Train MAE=1.17920, Val MAE=1.16727

# %%
print("\nBest MAE:", best_val_mae)
print("Best Params:", best_params)
# Out:
# Best MAE: 0.5765814882213787
# Best Params: {'hidden_size': 192, 'num_layers': 2, 'dropout': 0.19605154937100058, 'lr': 0.0019398356874841902}

# %% [markdown]
# Training with the Best Hyperparameters
# - Training till 200 epochs
# - If val mae does not improve for 20 epochs, stop the training process
# - Adam opitmizer

# %%
print("\nFinal Training with best hyperparameters")


hs = int(best_params["hidden_size"])
nl = int(best_params["num_layers"])
dp = float(best_params["dropout"])
lr = float(best_params["lr"])

print("Using:", hs, nl, dp, lr)


final_model = SimpleLSTM(input_size, hs, nl, dp).to(device)

optimizer = torch.optim.Adam(final_model.parameters(), lr=lr)
criterion = nn.L1Loss()


scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer,mode="min")


early_stop_patience = 20
best_val = float("inf")
patience_counter = 0

train_hist = []
val_hist = []

EPOCHS = 200

for epoch in range(EPOCHS):


    final_model.train()
    train_loss_total = 0

    for Xb, yb in train_loader:
        Xb, yb = Xb.to(device), yb.to(device)
        optimizer.zero_grad()
        pred = final_model(Xb)
        loss = criterion(pred, yb)
        loss.backward()
        optimizer.step()
        train_loss_total += loss.item()

    train_mae = train_loss_total / len(train_loader)
    train_hist.append(train_mae)


    final_model.eval()
    val_loss_total = 0

    with torch.no_grad():
        for Xb, yb in val_loader:
            Xb, yb = Xb.to(device), yb.to(device)
            val_loss_total += criterion(final_model(Xb), yb).item()

    val_mae = val_loss_total / len(val_loader)
    val_hist.append(val_mae)

    print(f"[FINAL] Epoch {epoch+1}/{EPOCHS} | Train MAE={train_mae:.5f} | Val MAE={val_mae:.5f}")


    scheduler.step(val_mae)

    if val_mae < best_val:
        best_val = val_mae
        best_weights = final_model.state_dict().copy()
        patience_counter = 0
    else:
        patience_counter += 1

    if patience_counter >= early_stop_patience:
        
# [FINAL] Epoch 180/200 | Train MAE=0.26499 | Val MAE=0.28472
# [FINAL] Epoch 181/200 | Train MAE=0.26494 | Val MAE=0.28356
# [FINAL] Epoch 182/200 | Train MAE=0.26520 | Val MAE=0.28621
# [FINAL] Epoch 183/200 | Train MAE=0.26467 | Val MAE=0.28312
# [FINAL] Epoch 184/200 | Train MAE=0.26474 | Val MAE=0.28482
# [FINAL] Epoch 185/200 | Train MAE=0.26439 | Val MAE=0.28354
# [FINAL] Epoch 186/200 | Train MAE=0.26429 | Val MAE=0.28303
# [FINAL] Epoch 187/200 | Train MAE=0.26416 | Val MAE=0.28370
# [FINAL] Epoch 188/200 | Train MAE=0.26391 | Val MAE=0.28293
# [FINAL] Epoch 189/200 | Train MAE=0.26390 | Val MAE=0.28297
# [FINAL] Epoch 190/200 | Train MAE=0.26357 | Val MAE=0.28387
# [FINAL] Epoch 191/200 | Train MAE=0.26382 | Val MAE=0.28422
# [FINAL] Epoch 192/200 | Train MAE=0.26334 | Val MAE=0.28354
# [FINAL] Epoch 193/200 | Train MAE=0.26334 | Val MAE=0.28291
# [FINAL] Epoch 194/200 | Train MAE=0.26320 | Val MAE=0.28331
# [FINAL] Epoch 195/200 | Train MAE=0.26302 | Val MAE=0.28444
# [FINAL] Epoch 196/200 | Train MAE=0.26338 | Val MAE=0.29987
# [FINAL] Epoch 197/200 | Train MAE=0.26426 | Val MAE=0.28397
# [FINAL] Epoch 198/200 | Train MAE=0.26297 | Val MAE=0.28339
# [FINAL] Epoch 199/200 | Train MAE=0.26289 | Val MAE=0.28381
# [FINAL] Epoch 200/200 | Train MAE=0.26013 | Val MAE=0.28161
# <All keys matched successfully>

# %%
print(final_model)
# Out:
# SimpleLSTM(
#   (lstm): LSTM(9, 192, num_layers=2, batch_first=True, dropout=0.19605154937100058)
#   (fc): Linear(in_features=192, out_features=1, bias=True)
# )

# %% [markdown]
# Visualization of Train MAE and Validation MAE

# %%
plt.figure(figsize=(8,5))
plt.plot(train_hist, label="Train MAE")
plt.plot(val_hist, label="Validation MAE")
plt.title("Training Curve (LSTM) (Early Stopping)")
plt.xlabel("Epoch")
plt.ylabel("MAE")
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# Testing of Trained LSTM on test data. <br>
#
# -Collection of prediction

# %%
final_model.eval()
preds = []

with torch.no_grad():
    for Xb in test_loader:
        Xb = Xb.to(device)
        preds.append(final_model(Xb).cpu().numpy())

preds = np.concatenate(preds).reshape(-1)
print("Predictions shape:", preds.shape)
# Out:
# Predictions shape: (4024000,)

# %% [markdown]
# Kaggle Submission requires the predictions to be in .csv format.<br>
# With two columns ID and prediction columns

# %%
submission = pd.DataFrame({
    "id": test_df["id"],
    "pressure": preds
})

submission.to_csv("LSTM_no_feature_submission.csv", index=False)
print("Saved submission.csv")
submission.head()
# Out:
# Saved submission.csv
#    id  pressure
# 0   1  6.421928
# 1   2  6.137354
# 2   3  7.048872
# 3   4  7.611680
# 4   5  9.083241

# %%
from google.colab import files

# Download
files.download('LSTM_no_feature_submission.csv')
